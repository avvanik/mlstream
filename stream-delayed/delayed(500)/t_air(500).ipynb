# %%
# %matplotlib ipympl
import numpy as np
import pandas as pd

from skmultiflow.trees import HoeffdingTreeClassifier
from skmultiflow.trees import HoeffdingAdaptiveTreeClassifier
from skmultiflow.trees import ExtremelyFastDecisionTreeClassifier
from skmultiflow.meta import AdaptiveRandomForestClassifier
from skmultiflow.bayes import NaiveBayes
from skmultiflow.meta import AccuracyWeightedEnsembleClassifier
from skmultiflow.lazy import KNNADWINClassifier

from skmultiflow.data import TemporalDataStream
from skmultiflow.data.file_stream import FileStream
from skmultiflow.data.data_stream import DataStream

from skmultiflow.evaluation import EvaluatePrequentialDelayed
from skmultiflow.evaluation import EvaluatePrequential

# %%
import warnings
warnings.filterwarnings('ignore')

#set columns
attribute = ["Airline","Flight","AirportFrom","AirportTo","DayOfWeek","Time","Length"]
target = "Delay"
timestamp = "datetime"

#read csv 
t_air = pd.read_csv("data/t_air.csv", )

#convert time to datetime
t_air[timestamp] = pd.to_datetime(t_air[timestamp])

#get X, y and time
X = t_air[attribute].values
y = t_air[target].values
time = t_air[timestamp].values

#set a delay
delay_time = 500

#create stream
t_air_stream = TemporalDataStream(X, y, time, sample_delay=delay_time, ordered=False)
nominal=['Airline', 'Flight', 'AirportFrom', 'AirportTo', 'DayOfWeek']

#set classifier
ht = HoeffdingTreeClassifier(leaf_prediction='nb', nominal_attributes=nominal)
hat = HoeffdingAdaptiveTreeClassifier(nominal_attributes=nominal)
efdt = ExtremelyFastDecisionTreeClassifier(nominal_attributes=nominal)
arf = AdaptiveRandomForestClassifier(nominal_attributes=nominal)
snb = NaiveBayes(nominal_attributes=nominal)
awe = AccuracyWeightedEnsembleClassifier(n_estimators=15, base_estimator=NaiveBayes(nominal_attributes=nominal))
knn_adwin = KNNADWINClassifier(n_neighbors=10)

#set evaluator
evaluator = EvaluatePrequentialDelayed(n_wait=10,
                                pretrain_size=100,
                                max_samples=X.shape[0],
                                output_file='results_air_t2.csv',
                                metrics=['accuracy', 'kappa', 
                                         'precision', 'recall', 
                                         'f1', 'running_time', 
                                         'model_size'])

#evaluate
evaluator.evaluate(stream=t_air_stream, 
                   model=[ht, hat, efdt, arf, 
                          snb, awe, knn_adwin], 
                   model_names=['Hoeffding Tree', 'Hoeffding Adaptive Tree', 
                                'Extremely Fast Decision Tree', 
                                'Adaptive Random Forest', 
                                'Naive Bayes', 'Accuracy Weighted Ensembler', 'KNN ADWIN' ])
# Out:
# Prequential Evaluation Delayed
# Evaluating 1 target(s).
# Pre-training on 100 sample(s).
# Evaluating...
#  ###################- [95%] [368.45s]Processed samples: 10000
# Mean performance:
# Hoeffding Tree - Accuracy     : 0.5949
# Hoeffding Tree - Kappa        : 0.1130
# Hoeffding Tree - Precision: 0.5218
# Hoeffding Tree - Recall: 0.3052
# Hoeffding Tree - F1 score: 0.3851
# Hoeffding Tree - Training time (s)  : 1.58
# Hoeffding Tree - Testing time  (s)  : 1.56
# Hoeffding Tree - Total time    (s)  : 3.14
# Hoeffding Tree - Size (kB)          : 52.4365
# Hoeffding Adaptive Tree - Accuracy     : 0.5984
# Hoeffding Adaptive Tree - Kappa        : 0.1049
# Hoeffding Adaptive Tree - Precision: 0.5362
# Hoeffding Adaptive Tree - Recall: 0.2519
# Hoeffding Adaptive Tree - F1 score: 0.3428
# Hoeffding Adaptive Tree - Training time (s)  : 8.55
# Hoeffding Adaptive Tree - Testing time  (s)  : 0.96
# Hoeffding Adaptive Tree - Total time    (s)  : 9.50
# Hoeffding Adaptive Tree - Size (kB)          : 77.0010
# Extremely Fast Decision Tree - Accuracy     : 0.5977
# Extremely Fast Decision Tree - Kappa        : 0.1077
# Extremely Fast Decision Tree - Precision: 0.5323
# Extremely Fast Decision Tree - Recall: 0.2668
# Extremely Fast Decision Tree - F1 score: 0.3554
# Extremely Fast Decision Tree - Training time (s)  : 42.08
# Extremely Fast Decision Tree - Testing time  (s)  : 0.92
# Extremely Fast Decision Tree - Total time    (s)  : 43.00
# Extremely Fast Decision Tree - Size (kB)          : 73.1650
# Adaptive Random Forest - Accuracy     : 0.6371
# Adaptive Random Forest - Kappa        : 0.2049
# Adaptive Random Forest - Precision: 0.6096
# Adaptive Random Forest - Recall: 0.3536
# Adaptive Random Forest - F1 score: 0.4476
# Adaptive Random Forest - Training time (s)  : 90.17
# Adaptive Random Forest - Testing time  (s)  : 9.26
# Adaptive Random Forest - Total time    (s)  : 99.43
# Adaptive Random Forest - Size (kB)          : 10220.6768
# Naive Bayes - Accuracy     : 0.6113
# Naive Bayes - Kappa        : 0.1810
# Naive Bayes - Precision: 0.5386
# Naive Bayes - Recall: 0.4531
# Naive Bayes - F1 score: 0.4921
# Naive Bayes - Training time (s)  : 0.92
# Naive Bayes - Testing time  (s)  : 1.15
# Naive Bayes - Total time    (s)  : 2.07
# Naive Bayes - Size (kB)          : 12.7129
# Accuracy Weighted Ensembler - Accuracy     : 0.5548
# Accuracy Weighted Ensembler - Kappa        : 0.0645
# Accuracy Weighted Ensembler - Precision: 0.4588
# Accuracy Weighted Ensembler - Recall: 0.3937
# Accuracy Weighted Ensembler - F1 score: 0.4238
# Accuracy Weighted Ensembler - Training time (s)  : 11.64
# Accuracy Weighted Ensembler - Testing time  (s)  : 13.88
# Accuracy Weighted Ensembler - Total time    (s)  : 25.52
# Accuracy Weighted Ensembler - Size (kB)          : 434.8750
# KNN ADWIN - Accuracy     : 0.6070
# KNN ADWIN - Kappa        : 0.1254
# KNN ADWIN - Precision: 0.5571
# KNN ADWIN - Recall: 0.2670
# KNN ADWIN - F1 score: 0.3610
# KNN ADWIN - Training time (s)  : 6.65
# KNN ADWIN - Testing time  (s)  : 4.73
# KNN ADWIN - Total time    (s)  : 11.37
# KNN ADWIN - Size (kB)          : 529.2041
# [HoeffdingTreeClassifier(binary_split=False, grace_period=200,
#                          leaf_prediction='nb', max_byte_size=33554432,
#                          memory_estimate_period=1000000, nb_threshold=0,
#                          no_preprune=False,
#                          nominal_attributes=['Airline', 'Flight', 'AirportFrom',
#                                              'AirportTo', 'DayOfWeek'],
#                          remove_poor_atts=False, split_confidence=1e-07,
#                          split_criterion='info_gain', stop_mem_management=False,
#                          tie_threshold=0.05),
#  HoeffdingAdaptiveTreeClassifier(binary_split=False, bootstrap_sampling=True,
#                                  grace_period=200, leaf_prediction='nba',
#                                  max_byte_size=33554432,
#                                  memory_estimate_period=1000000, nb_threshold=0,
#                                  no_preprune=False,
#                                  nominal_attributes=['Airline', 'Flight',
#                                                      'AirportFrom', 'AirportTo',
#                                                      'DayOfWeek'],
#                                  random_state=None, remove_poor_atts=False,
#                                  split_confidence=1e-07,
#                                  split_criterion='info_gain',
#                                  stop_mem_management=False, tie_threshold=0.05),
#  ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                      leaf_prediction='nba',
#                                      max_byte_size=33554432,
#                                      memory_estimate_period=1000000,
#                                      min_samples_reevaluate=20, nb_threshold=0,
#                                      nominal_attributes=['Airline', 'Flight',
#                                                          'AirportFrom',
#                                                          'AirportTo',
#                                                          'DayOfWeek'],
#                                      split_confidence=1e-07,
#                                      split_criterion='info_gain',
#                                      stop_mem_management=False,
#                                      tie_threshold=0.05),
#  AdaptiveRandomForestClassifier(binary_split=False, disable_weighted_vote=False,
#                                 drift_detection_method=ADWIN(delta=0.001),
#                                 grace_period=50, lambda_value=6,
#                                 leaf_prediction='nba', max_byte_size=33554432,
#                                 max_features=3, memory_estimate_period=2000000,
#                                 n_estimators=10, nb_threshold=0,
#                                 no_preprune=False,
#                                 nominal_attributes=['Airline', 'Flight',
#                                                     'AirportFrom', 'AirportTo',
#                                                     'DayOfWeek'],
#                                 performance_metric='acc', random_state=None,
#                                 remove_poor_atts=False, split_confidence=0.01,
#                                 split_criterion='info_gain',
#                                 stop_mem_management=False, tie_threshold=0.05,
#                                 warning_detection_method=ADWIN(delta=0.01)),
#  NaiveBayes(nominal_attributes=['Airline', 'Flight', 'AirportFrom', 'AirportTo',
#                                 'DayOfWeek']),
#  AccuracyWeightedEnsembleClassifier(base_estimator=NaiveBayes(nominal_attributes=['Airline',
#                                                                                   'Flight',
#                                                                                   'AirportFrom',
#                                                                                   'AirportTo',
#                                                                                   'DayOfWeek']),
#                                     n_estimators=15, n_kept_estimators=30,
#                                     n_splits=5, window_size=200),
#  KNNADWINClassifier(leaf_size=30, max_window_size=1000, metric='euclidean',
#                     n_neighbors=10)]
