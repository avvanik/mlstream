# %% [markdown]
# In diesem Notebook werden zwei Streaming Klassifizierungen mit 10.000 Instanzen durchgeführt:
#
# 1. Klassifizierung der agr_g_t Daten mit verspäteten Eintreffen der Label
# 2. Klassifizierung der agr_g Daten

# %%
import numpy as np
import pandas as pd

from skmultiflow.trees import HoeffdingTreeClassifier
from skmultiflow.trees import HoeffdingAdaptiveTreeClassifier
from skmultiflow.trees import ExtremelyFastDecisionTreeClassifier
from skmultiflow.meta import AdaptiveRandomForestClassifier
from skmultiflow.bayes import NaiveBayes
from skmultiflow.meta import AccuracyWeightedEnsembleClassifier
from skmultiflow.lazy import KNNADWINClassifier

from skmultiflow.data import TemporalDataStream
from skmultiflow.data.file_stream import FileStream
from skmultiflow.data.data_stream import DataStream

from skmultiflow.evaluation import EvaluatePrequentialDelayed
from skmultiflow.evaluation import EvaluatePrequential

# %%
import warnings
warnings.filterwarnings('ignore')

#set columns
attribute = ['salary', 'comission', 'age', 'elevel',
                 'car', 'zipcode', 'hvalue', 'hyears', 'loan']
target = "class"
timestamp = "datetime"

#read csv
t_agr_g1 = pd.read_csv("data/t_agr_g1.csv")

# Convert time to datetime
t_agr_g1[timestamp] = pd.to_datetime(t_agr_g1[timestamp])

#get X, y and time
X = t_agr_g1[attribute].values
y = t_agr_g1[target].values
time = t_agr_g1[timestamp].values

#set a delay of 1 day
delay_time = np.timedelta64(1, "D")

#create stream
t_agr_g1_stream = TemporalDataStream(X, y, time, sample_delay=delay_time, ordered=False)
nominal=['elevel', 'car', 'zipcode']

#set classifier
ht = HoeffdingTreeClassifier(leaf_prediction='nb', nominal_attributes=nominal)
hat = HoeffdingAdaptiveTreeClassifier(nominal_attributes=nominal)
efdt = ExtremelyFastDecisionTreeClassifier(nominal_attributes=nominal)
arf = AdaptiveRandomForestClassifier(nominal_attributes=nominal)
snb = NaiveBayes(nominal_attributes=nominal)
awe = AccuracyWeightedEnsembleClassifier(n_estimators=15, base_estimator=NaiveBayes(nominal_attributes=nominal))
knn_adwin = KNNADWINClassifier(n_neighbors=10)

# Set evaluator
evaluator = EvaluatePrequentialDelayed(
                                max_samples=X.shape[0],
                                n_wait=10,
                                pretrain_size=100,
                                output_file='results_t_agr_g1.csv',
                                metrics=['accuracy', 'kappa', 
                                         'precision', 'recall', 
                                         'f1', 'running_time', 
                                         'model_size'])

#evaluate
evaluator.evaluate(stream=t_agr_g1_stream, 
                   model=[ht, hat, efdt, arf, 
                          snb, awe, knn_adwin], 
                   model_names=['Hoeffding Tree', 'Hoeffding Adaptive Tree', 
                                'Extremely Fast Decision Tree', 
                                'Adaptive Random Forest', 
                                'Naive Bayes', 'Accuracy Weighted Ensembler', 'KNN ADWIN'])
# Out:
# Prequential Evaluation Delayed
# Evaluating 1 target(s).
# Pre-training on 100 sample(s).
# Evaluating...
#  ###################- [95%] [504.73s]Processed samples: 10000
# Mean performance:
# Hoeffding Tree - Accuracy     : 0.4694
# Hoeffding Tree - Kappa        : -0.0354
# Hoeffding Tree - Precision: 0.5932
# Hoeffding Tree - Recall: 0.4304
# Hoeffding Tree - F1 score: 0.4989
# Hoeffding Tree - Training time (s)  : 1.00
# Hoeffding Tree - Testing time  (s)  : 1.31
# Hoeffding Tree - Total time    (s)  : 2.31
# Hoeffding Tree - Size (kB)          : 63.1826
# Hoeffding Adaptive Tree - Accuracy     : 0.4631
# Hoeffding Adaptive Tree - Kappa        : -0.0182
# Hoeffding Adaptive Tree - Precision: 0.6010
# Hoeffding Adaptive Tree - Recall: 0.3722
# Hoeffding Adaptive Tree - F1 score: 0.4597
# Hoeffding Adaptive Tree - Training time (s)  : 3.63
# Hoeffding Adaptive Tree - Testing time  (s)  : 1.08
# Hoeffding Adaptive Tree - Total time    (s)  : 4.71
# Hoeffding Adaptive Tree - Size (kB)          : 60.1299
# Extremely Fast Decision Tree - Accuracy     : 0.4694
# Extremely Fast Decision Tree - Kappa        : -0.0354
# Extremely Fast Decision Tree - Precision: 0.5932
# Extremely Fast Decision Tree - Recall: 0.4304
# Extremely Fast Decision Tree - F1 score: 0.4989
# Extremely Fast Decision Tree - Training time (s)  : 51.08
# Extremely Fast Decision Tree - Testing time  (s)  : 0.83
# Extremely Fast Decision Tree - Total time    (s)  : 51.91
# Extremely Fast Decision Tree - Size (kB)          : 101.9893
# Adaptive Random Forest - Accuracy     : 0.4387
# Adaptive Random Forest - Kappa        : -0.0879
# Adaptive Random Forest - Precision: 0.5608
# Adaptive Random Forest - Recall: 0.3928
# Adaptive Random Forest - F1 score: 0.4620
# Adaptive Random Forest - Training time (s)  : 69.51
# Adaptive Random Forest - Testing time  (s)  : 5.44
# Adaptive Random Forest - Total time    (s)  : 74.95
# Adaptive Random Forest - Size (kB)          : 5943.6338
# Naive Bayes - Accuracy     : 0.4694
# Naive Bayes - Kappa        : -0.0354
# Naive Bayes - Precision: 0.5932
# Naive Bayes - Recall: 0.4304
# Naive Bayes - F1 score: 0.4989
# Naive Bayes - Training time (s)  : 0.44
# Naive Bayes - Testing time  (s)  : 0.80
# Naive Bayes - Total time    (s)  : 1.24
# Naive Bayes - Size (kB)          : 15.6777
# Accuracy Weighted Ensembler - Accuracy     : 0.3864
# Accuracy Weighted Ensembler - Kappa        : 0.0000
# Accuracy Weighted Ensembler - Precision: 0.0000
# Accuracy Weighted Ensembler - Recall: 0.0000
# Accuracy Weighted Ensembler - F1 score: 0.0000
# Accuracy Weighted Ensembler - Training time (s)  : 12.19
# Accuracy Weighted Ensembler - Testing time  (s)  : 0.05
# Accuracy Weighted Ensembler - Total time    (s)  : 12.24
# Accuracy Weighted Ensembler - Size (kB)          : 540.7148
# KNN ADWIN - Accuracy     : 0.4365
# KNN ADWIN - Kappa        : -0.0642
# KNN ADWIN - Precision: 0.5676
# KNN ADWIN - Recall: 0.3422
# KNN ADWIN - F1 score: 0.4270
# KNN ADWIN - Training time (s)  : 7.16
# KNN ADWIN - Testing time  (s)  : 3.06
# KNN ADWIN - Total time    (s)  : 10.22
# KNN ADWIN - Size (kB)          : 606.5283
# [HoeffdingTreeClassifier(binary_split=False, grace_period=200,
#                          leaf_prediction='nb', max_byte_size=33554432,
#                          memory_estimate_period=1000000, nb_threshold=0,
#                          no_preprune=False,
#                          nominal_attributes=['elevel', 'car', 'zipcode'],
#                          remove_poor_atts=False, split_confidence=1e-07,
#                          split_criterion='info_gain', stop_mem_management=False,
#                          tie_threshold=0.05),
#  HoeffdingAdaptiveTreeClassifier(binary_split=False, bootstrap_sampling=True,
#                                  grace_period=200, leaf_prediction='nba',
#                                  max_byte_size=33554432,
#                                  memory_estimate_period=1000000, nb_threshold=0,
#                                  no_preprune=False,
#                                  nominal_attributes=['elevel', 'car', 'zipcode'],
#                                  random_state=None, remove_poor_atts=False,
#                                  split_confidence=1e-07,
#                                  split_criterion='info_gain',
#                                  stop_mem_management=False, tie_threshold=0.05),
#  ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                      leaf_prediction='nba',
#                                      max_byte_size=33554432,
#                                      memory_estimate_period=1000000,
#                                      min_samples_reevaluate=20, nb_threshold=0,
#                                      nominal_attributes=['elevel', 'car',
#                                                          'zipcode'],
#                                      split_confidence=1e-07,
#                                      split_criterion='info_gain',
#                                      stop_mem_management=False,
#                                      tie_threshold=0.05),
#  AdaptiveRandomForestClassifier(binary_split=False, disable_weighted_vote=False,
#                                 drift_detection_method=ADWIN(delta=0.001),
#                                 grace_period=50, lambda_value=6,
#                                 leaf_prediction='nba', max_byte_size=33554432,
#                                 max_features=3, memory_estimate_period=2000000,
#                                 n_estimators=10, nb_threshold=0,
#                                 no_preprune=False,
#                                 nominal_attributes=['elevel', 'car', 'zipcode'],
#                                 performance_metric='acc', random_state=None,
#                                 remove_poor_atts=False, split_confidence=0.01,
#                                 split_criterion='info_gain',
#                                 stop_mem_management=False, tie_threshold=0.05,
#                                 warning_detection_method=ADWIN(delta=0.01)),
#  NaiveBayes(nominal_attributes=['elevel', 'car', 'zipcode']),
#  AccuracyWeightedEnsembleClassifier(base_estimator=NaiveBayes(nominal_attributes=['elevel',
#                                                                                   'car',
#                                                                                   'zipcode']),
#                                     n_estimators=15, n_kept_estimators=30,
#                                     n_splits=5, window_size=200),
#  KNNADWINClassifier(leaf_size=30, max_window_size=1000, metric='euclidean',
#                     n_neighbors=10)]

# %%
#drop timestamp
t_agr_g1 = pd.read_csv('data/t_agr_g1.csv')
agr_g1 = t_agr_g1.drop(['datetime'], axis=1)

#create stream
agr_g1_stream = DataStream(agr_g1)

#set classifier
ht = HoeffdingTreeClassifier(leaf_prediction='nb', nominal_attributes=nominal)
hat = HoeffdingAdaptiveTreeClassifier(nominal_attributes=nominal)
efdt = ExtremelyFastDecisionTreeClassifier(nominal_attributes=nominal)
arf = AdaptiveRandomForestClassifier(nominal_attributes=nominal)
snb = NaiveBayes(nominal_attributes=nominal)
awe = AccuracyWeightedEnsembleClassifier(n_estimators=15, base_estimator=NaiveBayes(nominal_attributes=nominal))
knn_adwin = KNNADWINClassifier(n_neighbors=10)

#set evaluator
evaluator = EvaluatePrequential(
                                max_samples=10000,
                                n_wait=10,
                                pretrain_size=100,
                                metrics=['accuracy', 'kappa', 
                                         'precision', 'recall', 
                                         'f1', 'running_time', 
                                         'model_size'])

#evaluate
evaluator.evaluate(stream=agr_g1_stream, 
                   model=[ht, hat, efdt, arf, 
                          snb, awe, knn_adwin], 
                   model_names=['Hoeffding Tree', 'Hoeffding Adaptive Tree', 
                                'Extremely Fast Decision Tree', 
                                'Adaptive Random Forest', 
                                'Naive Bayes', 'Accuracy Weighted Ensembler', 'KNN ADWIN' ])
# Out:
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 100 sample(s).
# Evaluating...
#  #################### [100%] [249.61s]
# Processed samples: 10000
# Mean performance:
# Hoeffding Tree - Accuracy     : 0.7297
# Hoeffding Tree - Kappa        : 0.4076
# Hoeffding Tree - Precision: 0.7474
# Hoeffding Tree - Recall: 0.8447
# Hoeffding Tree - F1 score: 0.7931
# Hoeffding Tree - Training time (s)  : 0.88
# Hoeffding Tree - Testing time  (s)  : 1.23
# Hoeffding Tree - Total time    (s)  : 2.11
# Hoeffding Tree - Size (kB)          : 71.7100
# Hoeffding Adaptive Tree - Accuracy     : 0.7372
# Hoeffding Adaptive Tree - Kappa        : 0.4272
# Hoeffding Adaptive Tree - Precision: 0.7570
# Hoeffding Adaptive Tree - Recall: 0.8415
# Hoeffding Adaptive Tree - F1 score: 0.7970
# Hoeffding Adaptive Tree - Training time (s)  : 4.80
# Hoeffding Adaptive Tree - Testing time  (s)  : 1.04
# Hoeffding Adaptive Tree - Total time    (s)  : 5.84
# Hoeffding Adaptive Tree - Size (kB)          : 61.4385
# Extremely Fast Decision Tree - Accuracy     : 0.7341
# Extremely Fast Decision Tree - Kappa        : 0.4152
# Extremely Fast Decision Tree - Precision: 0.7480
# Extremely Fast Decision Tree - Recall: 0.8542
# Extremely Fast Decision Tree - F1 score: 0.7976
# Extremely Fast Decision Tree - Training time (s)  : 62.81
# Extremely Fast Decision Tree - Testing time  (s)  : 0.84
# Extremely Fast Decision Tree - Total time    (s)  : 63.65
# Extremely Fast Decision Tree - Size (kB)          : 131.8916
# Adaptive Random Forest - Accuracy     : 0.7803
# Adaptive Random Forest - Kappa        : 0.5230
# Adaptive Random Forest - Precision: 0.7920
# Adaptive Random Forest - Recall: 0.8704
# Adaptive Random Forest - F1 score: 0.8293
# Adaptive Random Forest - Training time (s)  : 72.03
# Adaptive Random Forest - Testing time  (s)  : 5.99
# Adaptive Random Forest - Total time    (s)  : 78.02
# Adaptive Random Forest - Size (kB)          : 5533.0400
# Naive Bayes - Accuracy     : 0.6644
# Naive Bayes - Kappa        : 0.2610
# Naive Bayes - Precision: 0.6975
# Naive Bayes - Recall: 0.7995
# Naive Bayes - F1 score: 0.7450
# Naive Bayes - Training time (s)  : 0.49
# Naive Bayes - Testing time  (s)  : 0.86
# Naive Bayes - Total time    (s)  : 1.35
# Naive Bayes - Size (kB)          : 17.1895
# Accuracy Weighted Ensembler - Accuracy     : 0.7117
# Accuracy Weighted Ensembler - Kappa        : 0.4018
# Accuracy Weighted Ensembler - Precision: 0.7802
# Accuracy Weighted Ensembler - Recall: 0.7378
# Accuracy Weighted Ensembler - F1 score: 0.7584
# Accuracy Weighted Ensembler - Training time (s)  : 13.13
# Accuracy Weighted Ensembler - Testing time  (s)  : 10.13
# Accuracy Weighted Ensembler - Total time    (s)  : 23.26
# Accuracy Weighted Ensembler - Size (kB)          : 592.8086
# KNN ADWIN - Accuracy     : 0.6912
# KNN ADWIN - Kappa        : 0.3553
# KNN ADWIN - Precision: 0.7567
# KNN ADWIN - Recall: 0.7317
# KNN ADWIN - F1 score: 0.7440
# KNN ADWIN - Training time (s)  : 7.13
# KNN ADWIN - Testing time  (s)  : 5.43
# KNN ADWIN - Total time    (s)  : 12.56
# KNN ADWIN - Size (kB)          : 645.5908
# [HoeffdingTreeClassifier(binary_split=False, grace_period=200,
#                          leaf_prediction='nb', max_byte_size=33554432,
#                          memory_estimate_period=1000000, nb_threshold=0,
#                          no_preprune=False,
#                          nominal_attributes=['elevel', 'car', 'zipcode'],
#                          remove_poor_atts=False, split_confidence=1e-07,
#                          split_criterion='info_gain', stop_mem_management=False,
#                          tie_threshold=0.05),
#  HoeffdingAdaptiveTreeClassifier(binary_split=False, bootstrap_sampling=True,
#                                  grace_period=200, leaf_prediction='nba',
#                                  max_byte_size=33554432,
#                                  memory_estimate_period=1000000, nb_threshold=0,
#                                  no_preprune=False,
#                                  nominal_attributes=['elevel', 'car', 'zipcode'],
#                                  random_state=None, remove_poor_atts=False,
#                                  split_confidence=1e-07,
#                                  split_criterion='info_gain',
#                                  stop_mem_management=False, tie_threshold=0.05),
#  ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                      leaf_prediction='nba',
#                                      max_byte_size=33554432,
#                                      memory_estimate_period=1000000,
#                                      min_samples_reevaluate=20, nb_threshold=0,
#                                      nominal_attributes=['elevel', 'car',
#                                                          'zipcode'],
#                                      split_confidence=1e-07,
#                                      split_criterion='info_gain',
#                                      stop_mem_management=False,
#                                      tie_threshold=0.05),
#  AdaptiveRandomForestClassifier(binary_split=False, disable_weighted_vote=False,
#                                 drift_detection_method=ADWIN(delta=0.001),
#                                 grace_period=50, lambda_value=6,
#                                 leaf_prediction='nba', max_byte_size=33554432,
#                                 max_features=3, memory_estimate_period=2000000,
#                                 n_estimators=10, nb_threshold=0,
#                                 no_preprune=False,
#                                 nominal_attributes=['elevel', 'car', 'zipcode'],
#                                 performance_metric='acc', random_state=None,
#                                 remove_poor_atts=False, split_confidence=0.01,
#                                 split_criterion='info_gain',
#                                 stop_mem_management=False, tie_threshold=0.05,
#                                 warning_detection_method=ADWIN(delta=0.01)),
#  NaiveBayes(nominal_attributes=['elevel', 'car', 'zipcode']),
#  AccuracyWeightedEnsembleClassifier(base_estimator=NaiveBayes(nominal_attributes=['elevel',
#                                                                                   'car',
#                                                                                   'zipcode']),
#                                     n_estimators=15, n_kept_estimators=30,
#                                     n_splits=5, window_size=200),
#  KNNADWINClassifier(leaf_size=30, max_window_size=1000, metric='euclidean',
#                     n_neighbors=10)]
