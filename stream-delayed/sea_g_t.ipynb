# %%
import numpy as np
import pandas as pd

from skmultiflow.trees import HoeffdingTreeClassifier
from skmultiflow.trees import HoeffdingAdaptiveTreeClassifier
from skmultiflow.trees import ExtremelyFastDecisionTreeClassifier
from skmultiflow.meta import AdaptiveRandomForestClassifier
from skmultiflow.bayes import NaiveBayes
from skmultiflow.meta import AccuracyWeightedEnsembleClassifier
from skmultiflow.lazy import KNNADWINClassifier

from skmultiflow.data import TemporalDataStream

from skmultiflow.evaluation import EvaluatePrequentialDelayed

# %%
import warnings
warnings.filterwarnings('ignore')

attribute = ['attrib1', 'attrib2', 'attrib3']
target = "class"
timestamp = "datetime"

# Read a csv with stream data
sea_g_t = pd.read_csv("data/sea_g_t.csv")
# Convert time column to datetime
sea_g_t[timestamp] = pd.to_datetime(sea_g_t[timestamp])

# Get X, y and time
X = sea_g_t[attribute].values
y = sea_g_t[target].values
time = sea_g_t[timestamp].values

# set a delay of 1 day
delay_time = np.timedelta64(1, "D")

# create strem
sea_g_t_stream = TemporalDataStream(X, y, time, sample_delay=delay_time, ordered=False)

ht = HoeffdingTreeClassifier(leaf_prediction='nb')
hat = HoeffdingAdaptiveTreeClassifier()
efdt = ExtremelyFastDecisionTreeClassifier()
arf = AdaptiveRandomForestClassifier()
snb = NaiveBayes()
awe = AccuracyWeightedEnsembleClassifier(n_estimators=15, base_estimator=NaiveBayes())
knn_adwin = KNNADWINClassifier(n_neighbors=10)

# Set the evaluator
evaluator = EvaluatePrequentialDelayed(batch_size=1,
                                n_wait=10,
                                pretrain_size=100,
                                max_samples=X.shape[0],
                                output_file='results_sea_a_t.csv',
                                metrics=['accuracy', 'kappa', 
                                         'precision', 'recall', 
                                         'f1', 'running_time', 
                                         'model_size'])

evaluator.evaluate(stream=sea_g_t_stream, 
                   model=[ht, hat, efdt, arf, 
                          snb, awe, knn_adwin], 
                   model_names=['Hoeffding Tree', 'Hoeffding Adaptive Tree', 
                                'Extremely Fast Decision Tree', 
                                'Adaptive Random Forest', 
                                'Naive Bayes', 'Accuracy Weighted Ensembler', 'KNN ADWIN' ])
# Out:
# Prequential Evaluation Delayed
# Evaluating 1 target(s).
# Pre-training on 100 sample(s).
# Evaluating...
#  ###################- [95%] [482.55s]Processed samples: 10000
# Mean performance:
# Hoeffding Tree - Accuracy     : 0.8014
# Hoeffding Tree - Kappa        : 0.5427
# Hoeffding Tree - Precision: 0.7967
# Hoeffding Tree - Recall: 0.9243
# Hoeffding Tree - F1 score: 0.8558
# Hoeffding Tree - Training time (s)  : 0.73
# Hoeffding Tree - Testing time  (s)  : 1.10
# Hoeffding Tree - Total time    (s)  : 1.83
# Hoeffding Tree - Size (kB)          : 38.6719
# Hoeffding Adaptive Tree - Accuracy     : 0.8279
# Hoeffding Adaptive Tree - Kappa        : 0.6061
# Hoeffding Adaptive Tree - Precision: 0.8187
# Hoeffding Adaptive Tree - Recall: 0.9377
# Hoeffding Adaptive Tree - F1 score: 0.8741
# Hoeffding Adaptive Tree - Training time (s)  : 2.94
# Hoeffding Adaptive Tree - Testing time  (s)  : 0.82
# Hoeffding Adaptive Tree - Total time    (s)  : 3.76
# Hoeffding Adaptive Tree - Size (kB)          : 126.2637
# Extremely Fast Decision Tree - Accuracy     : 0.8014
# Extremely Fast Decision Tree - Kappa        : 0.5427
# Extremely Fast Decision Tree - Precision: 0.7967
# Extremely Fast Decision Tree - Recall: 0.9243
# Extremely Fast Decision Tree - F1 score: 0.8558
# Extremely Fast Decision Tree - Training time (s)  : 23.50
# Extremely Fast Decision Tree - Testing time  (s)  : 0.56
# Extremely Fast Decision Tree - Total time    (s)  : 24.06
# Extremely Fast Decision Tree - Size (kB)          : 71.3457
# Adaptive Random Forest - Accuracy     : 0.7638
# Adaptive Random Forest - Kappa        : 0.4218
# Adaptive Random Forest - Precision: 0.7407
# Adaptive Random Forest - Recall: 0.9684
# Adaptive Random Forest - F1 score: 0.8394
# Adaptive Random Forest - Training time (s)  : 60.76
# Adaptive Random Forest - Testing time  (s)  : 4.37
# Adaptive Random Forest - Total time    (s)  : 65.13
# Adaptive Random Forest - Size (kB)          : 8532.8145
# Naive Bayes - Accuracy     : 0.8014
# Naive Bayes - Kappa        : 0.5427
# Naive Bayes - Precision: 0.7967
# Naive Bayes - Recall: 0.9243
# Naive Bayes - F1 score: 0.8558
# Naive Bayes - Training time (s)  : 0.32
# Naive Bayes - Testing time  (s)  : 0.52
# Naive Bayes - Total time    (s)  : 0.84
# Naive Bayes - Size (kB)          : 6.2764
# Accuracy Weighted Ensembler - Accuracy     : 0.3627
# Accuracy Weighted Ensembler - Kappa        : 0.0000
# Accuracy Weighted Ensembler - Precision: 0.0000
# Accuracy Weighted Ensembler - Recall: 0.0000
# Accuracy Weighted Ensembler - F1 score: 0.0000
# Accuracy Weighted Ensembler - Training time (s)  : 6.16
# Accuracy Weighted Ensembler - Testing time  (s)  : 0.05
# Accuracy Weighted Ensembler - Total time    (s)  : 6.21
# Accuracy Weighted Ensembler - Size (kB)          : 222.1768
# KNN ADWIN - Accuracy     : 0.8196
# KNN ADWIN - Kappa        : 0.5941
# KNN ADWIN - Precision: 0.8252
# KNN ADWIN - Recall: 0.9097
# KNN ADWIN - F1 score: 0.8654
# KNN ADWIN - Training time (s)  : 6.17
# KNN ADWIN - Testing time  (s)  : 3.01
# KNN ADWIN - Total time    (s)  : 9.18
# KNN ADWIN - Size (kB)          : 372.8525
# [HoeffdingTreeClassifier(binary_split=False, grace_period=200,
#                          leaf_prediction='nb', max_byte_size=33554432,
#                          memory_estimate_period=1000000, nb_threshold=0,
#                          no_preprune=False, nominal_attributes=None,
#                          remove_poor_atts=False, split_confidence=1e-07,
#                          split_criterion='info_gain', stop_mem_management=False,
#                          tie_threshold=0.05),
#  HoeffdingAdaptiveTreeClassifier(binary_split=False, bootstrap_sampling=True,
#                                  grace_period=200, leaf_prediction='nba',
#                                  max_byte_size=33554432,
#                                  memory_estimate_period=1000000, nb_threshold=0,
#                                  no_preprune=False, nominal_attributes=None,
#                                  random_state=None, remove_poor_atts=False,
#                                  split_confidence=1e-07,
#                                  split_criterion='info_gain',
#                                  stop_mem_management=False, tie_threshold=0.05),
#  ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                      leaf_prediction='nba',
#                                      max_byte_size=33554432,
#                                      memory_estimate_period=1000000,
#                                      min_samples_reevaluate=20, nb_threshold=0,
#                                      nominal_attributes=None,
#                                      split_confidence=1e-07,
#                                      split_criterion='info_gain',
#                                      stop_mem_management=False,
#                                      tie_threshold=0.05),
#  AdaptiveRandomForestClassifier(binary_split=False, disable_weighted_vote=False,
#                                 drift_detection_method=ADWIN(delta=0.001),
#                                 grace_period=50, lambda_value=6,
#                                 leaf_prediction='nba', max_byte_size=33554432,
#                                 max_features=2, memory_estimate_period=2000000,
#                                 n_estimators=10, nb_threshold=0,
#                                 no_preprune=False, nominal_attributes=None,
#                                 performance_metric='acc', random_state=None,
#                                 remove_poor_atts=False, split_confidence=0.01,
#                                 split_criterion='info_gain',
#                                 stop_mem_management=False, tie_threshold=0.05,
#                                 warning_detection_method=ADWIN(delta=0.01)),
#  NaiveBayes(nominal_attributes=None),
#  AccuracyWeightedEnsembleClassifier(base_estimator=NaiveBayes(nominal_attributes=None),
#                                     n_estimators=15, n_kept_estimators=30,
#                                     n_splits=5, window_size=200),
#  KNNADWINClassifier(leaf_size=30, max_window_size=1000, metric='euclidean',
#                     n_neighbors=10)]
