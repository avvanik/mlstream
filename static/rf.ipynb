# %% [markdown]
# Statische Random Forest Klassifizierung

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
import time

#set test size
p = 1000

#safe measures in list
accuracy = []
f1 = []
precision = []
recall = []
kappa = []
train_time = []
pred_time = []

#evaluate + safe measures in lists
def evaluate():
    accuracy.append(accuracy_score(y_test, y_pred))
    f1.append(f1_score(y_test, y_pred, average='weighted'))
    precision.append(precision_score(y_test, y_pred, average='weighted', zero_division=0))
    recall.append(recall_score(y_test, y_pred, average='weighted'))
    kappa.append(cohen_kappa_score(y_test, y_pred))
    train_time.append(stop_train-start_train)
    pred_time.append(stop_pred-start_pred)

# %%
#load data
led_g1 = pd.read_csv('data/led_g1.csv')

#divide features and target class
X = led_g1.drop(led_g1.iloc[:,-1:], axis=1)
y = led_g1.iloc[:,-1:]

#set test_size
n = p/len(led_g1)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n)

#set classifier
rf = RandomForestClassifier(n_estimators=15)

# fit model with train data
start_train = time.time()
rf.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = rf.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
led_g2 = pd.read_csv('data/led_g2.csv')

#divide features and target class
X = led_g2.drop(led_g2.iloc[:,-1:], axis=1)
y = led_g2.iloc[:,-1:]

#set test_size
n = p/len(led_g2)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n)

#set classifier
rf = RandomForestClassifier(n_estimators=15)

# fit model with train data
start_train = time.time()
rf.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = rf.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
agr_g = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/agr_g.csv')

#divide features and target class
X = agr_g.drop(agr_g.iloc[:,-1:], axis=1)
y = agr_g.iloc[:,-1:]

#set test_size
n = p/len(agr_g)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n)

#set classifier
rf = RandomForestClassifier(n_estimators=15)

# fit model with train data
start_train = time.time()
rf.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = rf.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
agr_a = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/agr_a.csv')

#divide features and target class
X = agr_a.drop(agr_a.iloc[:,-1:], axis=1)
y = agr_a.iloc[:,-1:]

#set test_size
n = p/len(agr_a)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n)

#set classifier
rf = RandomForestClassifier(n_estimators=10)

# fit model with train data
start_train = time.time()
rf.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = rf.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
sea_a = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/sea_a.csv')

#divide features and target class
X = sea_a.drop(sea_a.iloc[:,-1:], axis=1)
y = sea_a.iloc[:,-1:]

#set test_size
n = p/len(sea_a)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state = 42)

#set classifier
rf = RandomForestClassifier(n_estimators=10)

# fit model with train data
start_train = time.time()
rf.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = rf.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
sea_g1 = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/sea_g.csv')

#divide features and target class
X = sea_g1.drop(sea_g1.iloc[:,-1:], axis=1)
y = sea_g1.iloc[:,-1:]

#set test_size
n = p/len(sea_g1)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state = 42)

#set classifier
rf = RandomForestClassifier(n_estimators=10)

# fit model with train data
start_train = time.time()
rf.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = rf.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
sea_g2 = pd.read_csv('data/sea_g2.csv')

#divide features and target class
X = sea_g2.drop(sea_g2.iloc[:,-1:], axis=1)
y = sea_g2.iloc[:,-1:]

#set test_size
n = p/len(sea_g2)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n)

#set classifier
rf = RandomForestClassifier(n_estimators=15)

# fit model with train data
start_train = time.time()
rf.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = rf.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
sea_g3 = pd.read_csv('data/sea_g3.csv')

#divide features and target class
X = sea_g3.drop(sea_g3.iloc[:,-1:], axis=1)
y = sea_g3.iloc[:,-1:]

#set test_size
n = p/len(sea_g3)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n)

#set classifier
rf = RandomForestClassifier(n_estimators=15)

# fit model with train data
start_train = time.time()
rf.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = rf.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
air = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/airlines.csv')

#divide features and target class
X = air.drop(air.iloc[:,-1:], axis=1)
y = air.iloc[:,-1:]

#set test_size
n = p/len(air)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n)

#set classifier
rf = RandomForestClassifier(n_estimators=10)

# fit model with train data
start_train = time.time()
rf.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = rf.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
cov = pd.read_csv('covtype.csv')

#divide features and target class
X = cov.drop(cov.iloc[:,-1:], axis=1)
y = cov.iloc[:,-1:]

#set test_size
n = p/len(cov)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n)

#set classifier
rf = RandomForestClassifier(n_estimators=10)

# fit model with train data
start_train = time.time()
rf.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = rf.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
result= {
    'Datensatz':['led_g1', 'led_g2', 'agr_g', 'agr_a', 'sea_a', 'sea_g1', 'sea_g2', 'sea_g3', 'air', 'cov'],
    'Accuracy' :accuracy,
    'f1':f1,
    'Precision':precision,
    'Recall':recall,
    'Kappa':kappa,
    'Train Time':train_time,
    'Prediction Time':pred_time
          }

result = pd.DataFrame(result)
print(result)
# Out:
#   Datensatz  Accuracy        f1  Precision  Recall     Kappa  Train Time  \
# 0    led_g1     0.753  0.750849   0.752866   0.753  0.725387    1.928415
# 1    led_g2     0.220  0.217874   0.222107   0.220  0.133326    2.614461
# 2     agr_g     0.503  0.504491   0.508387   0.503  0.004686   53.313231
# 3     agr_a     0.563  0.563728   0.564860   0.563  0.119654   31.187852
# 4     sea_a     0.912  0.912177   0.912542   0.912  0.817136   38.693324
# 5    sea_g1     0.902  0.902203   0.902527   0.902  0.791606   36.890457
# 6    sea_g2     0.548  0.547746   0.547708   0.548  0.094729    5.468135
# 7    sea_g3     0.545  0.544382   0.547577   0.545  0.092678    5.813672
# 8       air     0.602  0.601423   0.600966   0.602  0.187702    9.823227
# 9       cov     0.956  0.955426   0.956362   0.956  0.929323   15.619081
#
#    Prediction Time
# 0         0.027971
# 1         0.169376
# 2         0.063802
# 3         0.035599
# 4         0.028574
# 5         0.029654
# 6         0.012006
# 7         0.010963
# 8         0.042361
# 9         0.025663

# %%
result.to_excel('results_rf.xlsx')
