# %% [markdown]
# Statische Random Forest Klassifizierung

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
import time

#set test size
p = 200

#safe measures in list
accuracy = []
f1 = []
precision = []
recall = []
kappa = []
train_time = []
pred_time = []

#evaluate + safe measures in lists
def evaluate():
    accuracy.append(accuracy_score(y_test, y_pred))
    f1.append(f1_score(y_test, y_pred, average='weighted'))
    precision.append(precision_score(y_test, y_pred, average='weighted', zero_division=0))
    recall.append(recall_score(y_test, y_pred, average='weighted'))
    kappa.append(cohen_kappa_score(y_test, y_pred))
    train_time.append(stop_train-start_train)
    pred_time.append(stop_pred-start_pred)

# %%
#load data
agr_g = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/agr_g.csv')

#divide features and target class
X = agr_g.drop(agr_g.iloc[:,-1:], axis=1)
y = agr_g.iloc[:,-1:]

#set test_size
n = p/len(agr_g)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n)

#set classifier
rf = RandomForestClassifier(n_estimators=10)

# fit model with train data
start_train = time.time()
rf.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = rf.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
agr_a = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/agr_a.csv')

#divide features and target class
X = agr_a.drop(agr_a.iloc[:,-1:], axis=1)
y = agr_a.iloc[:,-1:]

#set test_size
n = p/len(agr_a)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n)

#set classifier
rf = RandomForestClassifier(n_estimators=10)

# fit model with train data
start_train = time.time()
rf.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = rf.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
sea_a = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/sea_a.csv')

#divide features and target class
X = sea_a.drop(sea_a.iloc[:,-1:], axis=1)
y = sea_a.iloc[:,-1:]

#set test_size
n = p/len(sea_a)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state = 42)

#set classifier
rf = RandomForestClassifier(n_estimators=10)

# fit model with train data
start_train = time.time()
rf.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = rf.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
sea_g1 = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/sea_g.csv')

#divide features and target class
X = sea_g1.drop(sea_g1.iloc[:,-1:], axis=1)
y = sea_g1.iloc[:,-1:]

#set test_size
n = p/len(sea_g1)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state = 42)

#set classifier
rf = RandomForestClassifier(n_estimators=10)

# fit model with train data
start_train = time.time()
rf.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = rf.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
air = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/airlines.csv')

#divide features and target class
X = air.drop(air.iloc[:,-1:], axis=1)
y = air.iloc[:,-1:]

#set test_size
n = p/len(air)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n)

#set classifier
rf = RandomForestClassifier(n_estimators=10)

# fit model with train data
start_train = time.time()
rf.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = rf.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
elec = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/elec.csv')

#divide features and target class
X = elec.drop(elec.iloc[:,-1:], axis=1)
y = elec.iloc[:,-1:]

#set test_size
n = p/len(elec)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n)

#set classifier
rf = RandomForestClassifier(n_estimators=10)

# fit model with train data
start_train = time.time()
rf.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = rf.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
cov = pd.read_csv('covtype.csv')

#divide features and target class
X = cov.drop(cov.iloc[:,-1:], axis=1)
y = cov.iloc[:,-1:]

#set test_size
n = p/len(cov)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n)

#set classifier
rf = RandomForestClassifier(n_estimators=10)

# fit model with train data
start_train = time.time()
rf.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = rf.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
pok = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/poker/poker-hand-testing.data')

#divide features and target class
X = pok.drop(pok.iloc[:,-1:], axis=1)
y = pok.iloc[:,-1:]

#set test_size
n = p/len(pok)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n)

#set classifier
rf = RandomForestClassifier(n_estimators=10)

# fit model with train data
start_train = time.time()
rf.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = rf.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
result= {
    'Datensatz':['agr_g', 'agr_a', 'sea_a', 'sea_g1', 'air', 'elec', 'cov', 'pok'],
    'Accuracy' :accuracy,
    'f1':f1,
    'Precision':precision,
    'Recall':recall,
    'Kappa':kappa,
    'Train Time':train_time,
    'Prediction Time':pred_time
          }

result = pd.DataFrame(result)
print(result)
# Out:
#   Datensatz  Accuracy        f1  Precision  Recall     Kappa  Train Time  \
# 0     agr_g     0.530  0.530753   0.533200   0.530  0.060000   36.812260
# 1     agr_a     0.510  0.509555   0.509212   0.510  0.012097   38.282582
# 2     sea_a     0.905  0.905352   0.906847   0.905  0.806043   42.019869
# 3    sea_g1     0.915  0.914863   0.914775   0.915  0.813801   39.976737
# 4       air     0.540  0.538389   0.537203   0.540  0.053011   10.125093
# 5      elec     0.765  0.761731   0.765217   0.765  0.511536    0.567600
# 6       cov     0.910  0.908862   0.908526   0.910  0.853748   17.038096
# 7       pok     0.640  0.609993   0.589374   0.640  0.336406   28.716576
#
#    Prediction Time
# 0         0.018290
# 1         0.012540
# 2         0.013227
# 3         0.012766
# 4         0.009729
# 5         0.003226
# 6         0.011585
# 7         0.016594

# %%
result.to_excel('results_rf.xlsx')
