# %% [markdown]
# Statische (Gaussian) Naive Bayes Klassifizierung

# %%
import numpy as np
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
import time

#safe measures in list
accuracy = []
f1 = []
precision = []
recall = []
kappa = []
pred_time = []

# %%
#load data
agr_g = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/agr_g.csv')

#divide features and target class
X = agr_g.drop(agr_g.iloc[:,-1:], axis=1)
y = agr_g.iloc[:,-1:]

#set test_size
n = 10000/len(agr_g)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state=0)

#set classifier
nb = GaussianNB()

# fit model with train data
nb.fit(X_train, y_train.values.ravel())

#classify test data
start = time.time()
y_pred = nb.predict(X_test)
stop = time.time()

#safe measures
accuracy.append(accuracy_score(y_test, y_pred))
f1.append(f1_score(y_test, y_pred, average='weighted'))
precision.append(precision_score(y_test, y_pred, average='weighted'))
recall.append(recall_score(y_test, y_pred, average='weighted'))
kappa.append(cohen_kappa_score(y_test, y_pred))
pred_time.append(stop-start)

# %%
#load data
agr_a = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/agr_a.csv')

#divide features and target class
X = agr_a.drop(agr_a.iloc[:,-1:], axis=1)
y = agr_a.iloc[:,-1:]

#set test_size
n = 10000/len(agr_a)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state=0)

#set classifier
nb = GaussianNB()

# fit model with train data
nb.fit(X_train, y_train.values.ravel())

#classify test data
start = time.time()
y_pred = nb.predict(X_test)
stop = time.time()

#safe measures
accuracy.append(accuracy_score(y_test, y_pred))
f1.append(f1_score(y_test, y_pred, average='weighted'))
precision.append(precision_score(y_test, y_pred, average='weighted'))
recall.append(recall_score(y_test, y_pred, average='weighted'))
kappa.append(cohen_kappa_score(y_test, y_pred))
pred_time.append(stop-start)

# %%
#load data
sea_a = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/sea_a.csv')

#divide features and target class
X = sea_a.drop(sea_a.iloc[:,-1:], axis=1)
y = sea_a.iloc[:,-1:]

#set test_size
n = 10000/len(sea_a)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state = 42)

#set classifier
nb = GaussianNB()

# fit model with train data
nb.fit(X_train, y_train.values.ravel())

#classify test data
start = time.time()
y_pred = nb.predict(X_test)
stop = time.time()

#safe measures
accuracy.append(accuracy_score(y_test, y_pred))
f1.append(f1_score(y_test, y_pred, average='weighted'))
precision.append(precision_score(y_test, y_pred, average='weighted'))
recall.append(recall_score(y_test, y_pred, average='weighted'))
kappa.append(cohen_kappa_score(y_test, y_pred))
pred_time.append(stop-start)

# %%
#load data
sea_g = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/sea_g.csv')

#divide features and target class
X = sea_g.drop(sea_g.iloc[:,-1:], axis=1)
y = sea_g.iloc[:,-1:]

#set test_size
n = 10000/len(sea_g)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state = 42)

#set classifier
nb = GaussianNB()

# fit model with train data
nb.fit(X_train, y_train.values.ravel())

#classify test data
start = time.time()
y_pred = nb.predict(X_test)
stop = time.time()

#safe measures
accuracy.append(accuracy_score(y_test, y_pred))
f1.append(f1_score(y_test, y_pred, average='weighted'))
precision.append(precision_score(y_test, y_pred, average='weighted'))
recall.append(recall_score(y_test, y_pred, average='weighted'))
kappa.append(cohen_kappa_score(y_test, y_pred))
pred_time.append(stop-start)

# %%
#load data
air = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/airlines.csv')

#divide features and target class
X = air.drop(air.iloc[:,-1:], axis=1)
y = air.iloc[:,-1:]

#set test_size
n = 10000/len(air)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state=0)

#set classifier
nb = GaussianNB()

# fit model with train data
nb.fit(X_train, y_train.values.ravel())

#classify test data
start = time.time()
y_pred = nb.predict(X_test)
stop = time.time()


#safe measures
accuracy.append(accuracy_score(y_test, y_pred))
f1.append(f1_score(y_test, y_pred, average='weighted'))
precision.append(precision_score(y_test, y_pred, average='weighted'))
recall.append(recall_score(y_test, y_pred, average='weighted'))
kappa.append(cohen_kappa_score(y_test, y_pred))
pred_time.append(stop-start)

# %%
#load data
elec = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/elec.csv')

#divide features and target class
X = elec.drop(elec.iloc[:,-1:], axis=1)
y = elec.iloc[:,-1:]

#set test_size
n = 10000/len(elec)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state=0)

#set classifier
nb = GaussianNB()

# fit model with train data
nb.fit(X_train, y_train.values.ravel())

#classify test data
start = time.time()
y_pred = nb.predict(X_test)
stop = time.time()

#safe measures
accuracy.append(accuracy_score(y_test, y_pred))
f1.append(f1_score(y_test, y_pred, average='weighted'))
precision.append(precision_score(y_test, y_pred, average='weighted'))
recall.append(recall_score(y_test, y_pred, average='weighted'))
kappa.append(cohen_kappa_score(y_test, y_pred))
pred_time.append(stop-start)

# %%
#load data
cov = pd.read_csv('covtype.csv')

#divide features and target class
X = cov.drop(cov.iloc[:,-1:], axis=1)
y = cov.iloc[:,-1:]

#set test_size
n = 10000/len(cov)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state=0)

#set classifier
nb = GaussianNB()

# fit model with train data
nb.fit(X_train, y_train.values.ravel())

#classify test data
start = time.time()
y_pred = nb.predict(X_test)
stop = time.time()

#safe measures
accuracy.append(accuracy_score(y_test, y_pred))
f1.append(f1_score(y_test, y_pred, average='weighted'))
precision.append(precision_score(y_test, y_pred, average='weighted'))
recall.append(recall_score(y_test, y_pred, average='weighted'))
kappa.append(cohen_kappa_score(y_test, y_pred))
pred_time.append(stop-start)

# %%
#load data
pok = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/poker/poker-hand-testing.data')

#divide features and target class
X = pok.drop(pok.iloc[:,-1:], axis=1)
y = pok.iloc[:,-1:]

#set test_size
n = 10000/len(pok)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state=0)

#set classifier
nb = GaussianNB()

# fit model with train data
nb.fit(X_train, y_train.values.ravel())

#classify test data
start = time.time()
y_pred = nb.predict(X_test)
stop = time.time()

#safe measures
accuracy.append(accuracy_score(y_test, y_pred))
f1.append(f1_score(y_test, y_pred, average='weighted'))
precision.append(precision_score(y_test, y_pred, average='weighted', zero_division=0)) #check last paramter
recall.append(recall_score(y_test, y_pred, average='weighted'))
kappa.append(cohen_kappa_score(y_test, y_pred))
pred_time.append(stop-start)

# %%
result= {
    'Datensatz':['agr_g', 'agr_a', 'sea_a', 'sea_g', 'air', 'elec', 'cov', 'pok'],
    'Accuracy' :accuracy,
    'f1':f1,
    'Precision':precision,
    'Recall':recall,
    'Kappa':kappa,
    'Time':pred_time
          }
result = pd.DataFrame(result)
print(result)
# Out:
#   Datensatz  Accuracy        f1  Precision  Recall     Kappa
# 0     agr_g    0.6113  0.607863   0.610439  0.6113  0.214159
# 1     agr_a    0.6206  0.616921   0.620105  0.6206  0.232569
# 2       air    0.5747  0.560789   0.566320  0.5747  0.112998
# 3      elec    0.7296  0.701832   0.776715  0.7296  0.403612
# 4       cov    0.4644  0.422579   0.659094  0.4644  0.268550
# 5       pok    0.4977  0.330781   0.247705  0.4977  0.000000
