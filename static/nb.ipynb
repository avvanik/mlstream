# %% [markdown]
# Statische (Gaussian) Naive Bayes Klassifizierung

# %%
import numpy as np
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
import time

#set test size
p = 1000

#safe measures in list
accuracy = []
f1 = []
precision = []
recall = []
kappa = []
train_time = []
pred_time = []

#evaluate + safe measures in lists
def evaluate():
    accuracy.append(accuracy_score(y_test, y_pred))
    f1.append(f1_score(y_test, y_pred, average='weighted'))
    precision.append(precision_score(y_test, y_pred, average='weighted', zero_division=0))
    recall.append(recall_score(y_test, y_pred, average='weighted'))
    kappa.append(cohen_kappa_score(y_test, y_pred))
    train_time.append(stop_train-start_train)
    pred_time.append(stop_pred-start_pred)

# %%
#load data
led_g1 = pd.read_csv('data/led_g1.csv')

#divide features and target class
X = led_g1.drop(led_g1.iloc[:,-1:], axis=1)
y = led_g1.iloc[:,-1:]

#set test_size
n = p/len(led_g1)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state=0)

#set classifier
nb = GaussianNB()

# fit model with train data
start_train = time.time()
nb.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = nb.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
led_g2 = pd.read_csv('data/led_g2.csv')

#divide features and target class
X = led_g2.drop(led_g2.iloc[:,-1:], axis=1)
y = led_g2.iloc[:,-1:]

#set test_size
n = p/len(led_g2)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state=0)

#set classifier
nb = GaussianNB()

# fit model with train data
start_train = time.time()
nb.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = nb.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
agr_g = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/agr_g.csv')

#divide features and target class
X = agr_g.drop(agr_g.iloc[:,-1:], axis=1)
y = agr_g.iloc[:,-1:]

#set test_size
n = p/len(agr_g)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state=0)

#set classifier
nb = GaussianNB()

# fit model with train data
start_train = time.time()
nb.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = nb.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
agr_a = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/agr_a.csv')

#divide features and target class
X = agr_a.drop(agr_a.iloc[:,-1:], axis=1)
y = agr_a.iloc[:,-1:]

#set test_size
n = p/len(agr_a)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state=0)

#set classifier
nb = GaussianNB()

# fit model with train data
start_train = time.time()
nb.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = nb.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
sea_a = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/sea_a.csv')

#divide features and target class
X = sea_a.drop(sea_a.iloc[:,-1:], axis=1)
y = sea_a.iloc[:,-1:]

#set test_size
n = p/len(sea_a)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state = 42)

#set classifier
nb = GaussianNB()

# fit model with train data
start_train = time.time()
nb.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = nb.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
sea_g1 = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/sea_g.csv')

#divide features and target class
X = sea_g1.drop(sea_g1.iloc[:,-1:], axis=1)
y = sea_g1.iloc[:,-1:]

#set test_size
n = p/len(sea_g1)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state = 42)

#set classifier
nb = GaussianNB()

# fit model with train data
start_train = time.time()
nb.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = nb.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
sea_g2 = pd.read_csv('data/sea_g2.csv')

#divide features and target class
X = sea_g2.drop(sea_g2.iloc[:,-1:], axis=1)
y = sea_g2.iloc[:,-1:]

#set test_size
n = p/len(sea_g2)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state=0)

#set classifier
nb = GaussianNB()

# fit model with train data
start_train = time.time()
nb.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = nb.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
sea_g3 = pd.read_csv('data/sea_g3.csv')

#divide features and target class
X = sea_g3.drop(sea_g3.iloc[:,-1:], axis=1)
y = sea_g3.iloc[:,-1:]

#set test_size
n = p/len(sea_g3)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state=0)

#set classifier
nb = GaussianNB()

# fit model with train data
start_train = time.time()
nb.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = nb.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
air = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/airlines.csv')

#divide features and target class
X = air.drop(air.iloc[:,-1:], axis=1)
y = air.iloc[:,-1:]

#set test_size
n = p/len(air)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state=0)

#set classifier
nb = GaussianNB()

# fit model with train data
start_train = time.time()
nb.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = nb.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
cov = pd.read_csv('covtype.csv')

#divide features and target class
X = cov.drop(cov.iloc[:,-1:], axis=1)
y = cov.iloc[:,-1:]

#set test_size
n = p/len(cov)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state=0)

#set classifier
nb = GaussianNB()

# fit model with train data
start_train = time.time()
nb.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = nb.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
result= {
    'Datensatz':['led_g1', 'led_g2', 'agr_g', 'agr_a', 'sea_a', 'sea_g1', 'sea_g2', 'sea_g3', 'air', 'cov'],
    'Accuracy' :accuracy,
    'f1':f1,
    'Precision':precision,
    'Recall':recall,
    'Kappa':kappa,
    'Train Time':train_time,
    'Prediction Time':pred_time
          }
result = pd.DataFrame(result)
print(result)
# Out:
#   Datensatz  Accuracy        f1  Precision  Recall     Kappa  Train Time  \
# 0    led_g1     0.788  0.787006   0.791032   0.788  0.764114    0.131355
# 1    led_g2     0.247  0.238490   0.248263   0.247  0.164604    0.079514
# 2     agr_g     0.603  0.596927   0.602947   0.603  0.195542    0.403964
# 3     agr_a     0.621  0.616427   0.618577   0.621  0.226063    0.411002
# 4     sea_a     0.857  0.855731   0.856683   0.857  0.697067    0.234878
# 5    sea_g1     0.848  0.845595   0.847465   0.848  0.666778    0.207896
# 6    sea_g2     0.621  0.619557   0.624084   0.621  0.243314    0.033591
# 7    sea_g3     0.566  0.566037   0.566078   0.566  0.130470    0.024462
# 8       air     0.575  0.562928   0.564144   0.575  0.104743    0.176391
# 9       cov     0.458  0.415068   0.654456   0.458  0.268656    1.387200
#
#    Prediction Time
# 0         0.004606
# 1         0.003620
# 2         0.004490
# 3         0.003909
# 4         0.002405
# 5         0.002016
# 6         0.001680
# 7         0.001685
# 8         0.002094
# 9         0.017709

# %%
result.to_excel('results_nb.xlsx')
