# %% [markdown]
# Statische KNN Klassifizierung

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
import time

#set test size
p = 200

#safe measures in list
accuracy = []
f1 = []
precision = []
recall = []
kappa = []
train_time = []
pred_time = []

#evaluate + safe measures in lists
def evaluate():
    accuracy.append(accuracy_score(y_test, y_pred))
    f1.append(f1_score(y_test, y_pred, average='weighted'))
    precision.append(precision_score(y_test, y_pred, average='weighted', zero_division=0)) # zero_divison wird gesetzt damit ohne warnung 0 ausgegeben wird weil true positive + false positive == 0 
    recall.append(recall_score(y_test, y_pred, average='weighted'))
    kappa.append(cohen_kappa_score(y_test, y_pred))
    train_time.append(stop_train-start_train)
    pred_time.append(stop_pred-start_pred)

# %%
#load data
agr_g = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/agr_g.csv')

#divide features and target class
X = agr_g.drop(agr_g.iloc[:,-1:], axis=1)
y = agr_g.iloc[:,-1:]

#set test_size
n = p/len(agr_g)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n)

#set classifier
knn = KNeighborsClassifier(n_neighbors=3)

# fit model with train data
start_train = time.time()
knn.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = knn.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
agr_a = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/agr_a.csv')

#divide features and target class
X = agr_a.drop(agr_a.iloc[:,-1:], axis=1)
y = agr_a.iloc[:,-1:]

#set test_size
n = p/len(agr_a)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n)

#set classifier
knn = KNeighborsClassifier(n_neighbors=5)

# fit model with train data
start_train = time.time()
knn.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = knn.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
sea_a = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/sea_a.csv')

#divide features and target class
X = sea_a.drop(sea_a.iloc[:,-1:], axis=1)
y = sea_a.iloc[:,-1:]

#set test_size
n = p/len(sea_a)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state = 42)

#set classifier
knn = KNeighborsClassifier(n_neighbors=5)

# fit model with train data
start_train = time.time()
knn.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = knn.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
sea_g1 = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/sea_g.csv')

#divide features and target class
X = sea_g1.drop(sea_g1.iloc[:,-1:], axis=1)
y = sea_g1.iloc[:,-1:]

#set test_size
n = p/len(sea_g1)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state = 42)

#set classifier
knn = KNeighborsClassifier(n_neighbors=5)

# fit model with train data
start_train = time.time()
knn.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = knn.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
air = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/airlines.csv')

#divide features and target class
X = air.drop(air.iloc[:,-1:], axis=1)
y = air.iloc[:,-1:]

#set test_size
n = p/len(air)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n)

#set classifier
knn = KNeighborsClassifier(n_neighbors=5)

# fit model with train data
start_train = time.time()
knn.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = knn.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
elec = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/elec.csv')

#divide features and target class
X = elec.drop(elec.iloc[:,-1:], axis=1)
y = elec.iloc[:,-1:]

#set test_size
n = p/len(elec)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n)

#set classifier
knn = KNeighborsClassifier(n_neighbors=5)

# fit model with train data
start_train = time.time()
knn.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = knn.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
cov = pd.read_csv('covtype.csv')

#divide features and target class
X = cov.drop(cov.iloc[:,-1:], axis=1)
y = cov.iloc[:,-1:]

#set test_size
n = p/len(cov)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n)

#set classifier
knn = KNeighborsClassifier(n_neighbors=5)

# fit model with train data
start_train = time.time()
knn.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = knn.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
pok = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/poker/poker-hand-testing.data')

#divide features and target class
X = pok.drop(pok.iloc[:,-1:], axis=1)
y = pok.iloc[:,-1:]

#set test_size
n = p/len(pok)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n)

#set classifier
knn = KNeighborsClassifier(n_neighbors=5)

# fit model with train data
start_train = time.time()
knn.fit(X_train, y_train.values.ravel())
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = knn.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
result= {
    'Datensatz':['agr_g', 'agr_a', 'sea_a', 'sea_g1', 'air', 'elec', 'cov', 'pok'],
    'Accuracy' :accuracy,
    'f1':f1,
    'Precision':precision,
    'Recall':recall,
    'Kappa':kappa,
    'Train Time':train_time,
    'Prediction Time':pred_time
          }
result = pd.DataFrame(result)
print(result)
# Out:
#   Datensatz  Accuracy        f1  Precision  Recall     Kappa  Train Time  \
# 0     agr_g     0.575  0.571179   0.580283   0.575  0.153218  104.923255
# 1     agr_a     0.570  0.569220   0.568895   0.570  0.133327  105.334272
# 2     sea_a     0.905  0.905226   0.905866   0.905  0.805368    1.176015
# 3    sea_g1     0.930  0.929769   0.929741   0.930  0.846171    1.117151
# 4       air     0.640  0.637595   0.639852   0.640  0.273828    0.744606
# 5      elec     0.780  0.775990   0.777992   0.780  0.524427    0.167254
# 6       cov     0.965  0.964767   0.966302   0.965  0.944727    0.042054
# 7       pok     0.655  0.632273   0.611315   0.655  0.351077   23.674404
#
#    Prediction Time
# 0         0.011032
# 1         0.011757
# 2         0.007255
# 3         0.007680
# 4         0.007397
# 5         0.009702
# 6         2.805928
# 7         0.092232

# %%
result.to_excel('results_knn.xlsx')
