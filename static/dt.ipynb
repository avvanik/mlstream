# %% [markdown]
# Statische Decision Tree Klassifizierung

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
import time

#set test size
p = 200

#safe measures in list
accuracy = []
f1 = []
precision = []
recall = []
kappa = []
train_time = []
pred_time = []

#evaluate + safe measures in lists
def evaluate():
    accuracy.append(accuracy_score(y_test, y_pred))
    f1.append(f1_score(y_test, y_pred, average='weighted'))
    precision.append(precision_score(y_test, y_pred, average='weighted', zero_division=0))
    recall.append(recall_score(y_test, y_pred, average='weighted'))
    kappa.append(cohen_kappa_score(y_test, y_pred))
    train_time.append(stop_train-start_train)
    pred_time.append(stop_pred-start_pred)

# %%
#load data
agr_g = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/agr_g.csv')

#divide features and target class

#1 Features und Target Class voneinander trennen
X = agr_g.drop(agr_g.iloc[:,-1:], axis=1)
y = agr_g.iloc[:,-1:]

#2 Test und Training Daten definieren
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = (200/len(agr_g), random_state = 42)

#set classifier
dt = DecisionTreeClassifier()

# fit model with train data
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
agr_a = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/agr_a.csv')

#divide features and target class
X = agr_a.drop(agr_a.iloc[:,-1:], axis=1)
y = agr_a.iloc[:,-1:]

#set test_size
n = p/len(agr_a)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state = 42)

#set classifier
dt = DecisionTreeClassifier()

# fit model with train data
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
sea_a = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/sea_a.csv')

#divide features and target class
X = sea_a.drop(sea_a.iloc[:,-1:], axis=1)
y = sea_a.iloc[:,-1:]

#set test_size
n = p/len(sea_a)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state = 42)

#set classifier
dt = DecisionTreeClassifier()

# fit model with train data
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
sea_g1 = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/sea_g.csv')

#divide features and target class
X = sea_g1.drop(sea_g1.iloc[:,-1:], axis=1)
y = sea_g1.iloc[:,-1:]

#set test_size
n = p/len(sea_g1)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state = 42)

#set classifier
dt = DecisionTreeClassifier()

# fit model with train data
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
air = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/airlines.csv')

#divide features and target class
X = air.drop(air.iloc[:,-1:], axis=1)
y = air.iloc[:,-1:]

#set test_size
n = p/len(air)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state = 42)

#set classifier
dt = DecisionTreeClassifier()

# fit model with train data
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
elec = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/elec.csv')

#divide features and target class
X = elec.drop(elec.iloc[:,-1:], axis=1)
y = elec.iloc[:,-1:]

#set test_size
n = p/len(elec)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state = 42)

#set classifier
dt = DecisionTreeClassifier()

# fit model with train data
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
cov = pd.read_csv('covtype.csv')

#divide features and target class
X = cov.drop(cov.iloc[:,-1:], axis=1)
y = cov.iloc[:,-1:]

#set test_size
n = p/len(cov)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state = 42)

#set classifier
dt = DecisionTreeClassifier()

# fit model with train data
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
pok = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/poker/poker-hand-testing.data')

#divide features and target class
X = pok.drop(pok.iloc[:,-1:], axis=1)
y = pok.iloc[:,-1:]

#set test_size
n = p/len(pok)

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = n, random_state = 42)

#set classifier
dt = DecisionTreeClassifier()

# fit model with train data
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
result= {
    'Datensatz':['agr_g', 'agr_a', 'sea_a', 'sea_g1', 'air', 'elec', 'cov', 'pok'],
    'Accuracy' :accuracy,
    'f1':f1,
    'Precision':precision,
    'Recall':recall,
    'Kappa':kappa,
    'Train Time':train_time,
    'Prediction Time':pred_time
          }
result = pd.DataFrame(result)
print(result)
# Out:
#   Datensatz  Accuracy        f1  Precision  Recall     Kappa  Train Time  \
# 0     agr_g     0.520  0.516961   0.522438   0.520  0.043062    8.817590
# 1     agr_a     0.475  0.473935   0.474796   0.475 -0.050000    9.061049
# 2     sea_a     0.900  0.900164   0.900512   0.900  0.794767   10.396312
# 3    sea_g1     0.915  0.914571   0.914592   0.915  0.812610   10.821734
# 4       air     0.540  0.533279   0.542445   0.540  0.080000    2.212411
# 5      elec     0.770  0.768792   0.769000   0.770  0.526749    0.209469
# 6       cov     0.960  0.957936   0.958054   0.960  0.936072    7.384899
# 7       pok     0.655  0.653625   0.654876   0.655  0.379747    5.493890
#
#    Prediction Time
# 0         0.002326
# 1         0.001861
# 2         0.001796
# 3         0.001471
# 4         0.002005
# 5         0.001246
# 6         0.001430
# 7         0.002504

# %%
result.to_excel('results_dt.xlsx')
