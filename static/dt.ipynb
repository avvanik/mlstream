# %% [markdown]
# Statische Decision Tree Klassifizierung

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
import time

#safe measures in list
accuracy = []
f1 = []
precision = []
recall = []
kappa = []
train_time = []
pred_time = []

#evaluate + safe measures in lists
def evaluate():
    accuracy.append(accuracy_score(y_test, y_pred))
    f1.append(f1_score(y_test, y_pred, average='weighted'))
    precision.append(precision_score(y_test, y_pred, average='weighted', zero_division=0))
    recall.append(recall_score(y_test, y_pred, average='weighted'))
    kappa.append(cohen_kappa_score(y_test, y_pred))
    train_time.append(stop_train-start_train)
    pred_time.append(stop_pred-start_pred)

# %%
#load data
led_g1 = pd.read_csv('data/led_g1.csv')

#divide features and target class

#1 Features und Target Class voneinander trennen
X = led_g1.drop(led_g1.iloc[:,-1:], axis=1)
y = led_g1.iloc[:,-1:]

#class distribution
y.value_counts()

#2 Test und Training Daten definieren
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = (1000/len(led_g1)), random_state = 42)

#set classifier
dt = DecisionTreeClassifier(criterion='gini', splitter='best', 
                            max_depth=None, min_samples_split=2, 
                            min_samples_leaf=1, class_weight=None)

# fit model with train data
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
led_g2 = pd.read_csv('data/led_g2.csv')

#divide features and target class

#1 Features und Target Class voneinander trennen
X = led_g2.drop(led_g2.iloc[:,-1:], axis=1)
y = led_g2.iloc[:,-1:]

#class distribution
y.value_counts()

#2 Test und Training Daten definieren
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = (1000/len(led_g2)), random_state = 42)

#set classifier
dt = DecisionTreeClassifier(criterion='gini', splitter='best', 
                            max_depth=None, min_samples_split=2, 
                            min_samples_leaf=1, class_weight=None)

# fit model with train data
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
agr_g = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/agr_g.csv')

#divide features and target class

#1 Features und Target Class voneinander trennen
X = agr_g.drop(agr_g.iloc[:,-1:], axis=1)
y = agr_g.iloc[:,-1:]

#class distribution
y.value_counts()

#2 Test und Training Daten definieren
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = (1000/len(agr_g)), random_state = 42)

#set classifier
dt = DecisionTreeClassifier(criterion='gini', splitter='best', 
                            max_depth=None, min_samples_split=2, 
                            min_samples_leaf=1, class_weight=None)

# fit model with train data
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
agr_a = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/agr_a.csv')

#divide features and target class
X = agr_a.drop(agr_a.iloc[:,-1:], axis=1)
y = agr_a.iloc[:,-1:]

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = (1000/len(agr_a)), random_state = 42)

#set classifier
dt = DecisionTreeClassifier(criterion='gini', splitter='best', 
                            max_depth=None, min_samples_split=2, 
                            min_samples_leaf=1, class_weight=None)

# fit model with train data
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
sea_a = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/sea_a.csv')

#divide features and target class
X = sea_a.drop(sea_a.iloc[:,-1:], axis=1)
y = sea_a.iloc[:,-1:]

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =(1000/len(sea_a)), random_state = 42)

#set classifier
dt = DecisionTreeClassifier(criterion='gini', splitter='best', 
                            max_depth=None, min_samples_split=2, 
                            min_samples_leaf=1, class_weight=None)

# fit model with train data
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
sea_g1 = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/sea_g.csv')

#divide features and target class
X = sea_g1.drop(sea_g1.iloc[:,-1:], axis=1)
y = sea_g1.iloc[:,-1:]

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = (1000/len(sea_g1)), random_state = 42)

#set classifier
dt = DecisionTreeClassifier(criterion='gini', splitter='best', 
                            max_depth=None, min_samples_split=2, 
                            min_samples_leaf=1, class_weight=None)

# fit model with train data
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
sea_g2 = pd.read_csv('data/sea_g2.csv')

#divide features and target class
X = sea_g2.drop(sea_g2.iloc[:,-1:], axis=1)
y = sea_g2.iloc[:,-1:]

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = (1000/len(sea_g2)), random_state = 42)

#set classifier
dt = DecisionTreeClassifier(criterion='gini', splitter='best', 
                            max_depth=None, min_samples_split=2, 
                            min_samples_leaf=1, class_weight=None)

# fit model with train data
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
sea_g3 = pd.read_csv('data/sea_g3.csv')

#divide features and target class
X = sea_g3.drop(sea_g3.iloc[:,-1:], axis=1)
y = sea_g3.iloc[:,-1:]

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = (1000/len(sea_g3)), random_state = 42)

#set classifier
dt = DecisionTreeClassifier(criterion='gini', splitter='best', 
                            max_depth=None, min_samples_split=2, 
                            min_samples_leaf=1, class_weight=None)

# fit model with train data
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
air = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/airlines.csv')

#divide features and target class
X = air.drop(air.iloc[:,-1:], axis=1)
y = air.iloc[:,-1:]

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = (1000/len(air)), random_state = 42)

#set classifier
dt = DecisionTreeClassifier(criterion='gini', splitter='best', 
                            max_depth=None, min_samples_split=2, 
                            min_samples_leaf=1, class_weight=None)

# fit model with train data
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#load data
cov = pd.read_csv('covtype.csv')

#divide features and target class
X = cov.drop(cov.iloc[:,-1:], axis=1)
y = cov.iloc[:,-1:]

#split test and train data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = (1000/len(cov)), random_state = 42)

#set classifier
dt = DecisionTreeClassifier(criterion='gini', splitter='best', 
                            max_depth=None, min_samples_split=2, 
                            min_samples_leaf=1, class_weight=None)

# fit model with train data
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify test data
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
result= {
    'Datensatz':['led_g1', 'led_g2', 'agr_g', 'agr_a', 'sea_a', 'sea_g1', 'sea_g2', 'sea_g3', 'air', 'cov',],
    'Accuracy' :accuracy,
    'f1':f1,
    'Precision':precision,
    'Recall':recall,
    'Kappa':kappa,
    'Train Time':train_time,
    'Prediction Time':pred_time
          }
result = pd.DataFrame(result)
print(result)
# Out:
#   Datensatz  Accuracy        f1  Precision  Recall     Kappa  Train Time  \
# 0    led_g1     0.626  0.625483   0.625929   0.626  0.584087    0.724105
# 1    led_g2     0.163  0.163714   0.166050   0.163  0.070049    0.682127
# 2     agr_g     0.518  0.517650   0.517366   0.518  0.028191    9.545455
# 3     agr_a     0.504  0.503569   0.503283   0.504  0.002975    8.984826
# 4     sea_a     0.907  0.907133   0.907358   0.907  0.806500   11.342560
# 5    sea_g1     0.902  0.902104   0.902237   0.902  0.791159   11.927215
# 6    sea_g2     0.533  0.533072   0.533172   0.533  0.065125    1.246398
# 7    sea_g3     0.501  0.500907   0.501103   0.501  0.002168    1.556207
# 8       air     0.600  0.591915   0.594169   0.600  0.170438    2.561177
# 9       cov     0.953  0.953342   0.955275   0.953  0.926087    9.758513
#
#    Prediction Time
# 0         0.004259
# 1         0.002095
# 2         0.008663
# 3         0.008345
# 4         0.003159
# 5         0.002577
# 6         0.002051
# ...

# %%
result.to_excel('results_dt.xlsx')
