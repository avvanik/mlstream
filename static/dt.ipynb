# %% [markdown]
# In diesem Notebook werden 10 statische Klassifizierungen mit dem DT durchgeführt:
#
# 1. led_g1
# 2. leg_g2
# 3. sea_a
# 4. sea_g1
# 5. sea_g2
# 6. agr_a
# 7. agr_g1
# 8. agr_g2
# 9. air
# 10. cov

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
import time

#set test size
test = 1000

#metrics
accuracy = []
kappa = []
precision = []
recall = []
f1 = []
train_time = []
pred_time = []

#define method: evaluate + safe measures in lists
def evaluate():
    accuracy.append(accuracy_score(y_test, y_pred))
    kappa.append(cohen_kappa_score(y_test, y_pred))
    precision.append(precision_score(y_test, y_pred, average='weighted', zero_division=0))
    recall.append(recall_score(y_test, y_pred, average='weighted'))
    f1.append(f1_score(y_test, y_pred, average='weighted'))
    train_time.append(stop_train-start_train)
    pred_time.append(stop_pred-start_pred)

# %%
#read csv
led_g1 = pd.read_csv('data/led_g1.csv')

#get features and target class
X = led_g1.drop(led_g1.iloc[:,-1:], axis=1)
y = led_g1.iloc[:,-1:]

#set train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = (test/len(led_g1)), random_state = 42)

#set classifier
dt = DecisionTreeClassifier(criterion='gini', splitter='best', 
                            max_depth=None, min_samples_split=2, 
                            min_samples_leaf=1, class_weight=None)

#train model + measure time
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify data + measure time
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#read csv
led_g2 = pd.read_csv('data/led_g2.csv')

#get features and target class
X = led_g2.drop(led_g2.iloc[:,-1:], axis=1)
y = led_g2.iloc[:,-1:]

#set train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = (test/len(led_g2)), random_state = 42)

#set classifier
dt = DecisionTreeClassifier(criterion='gini', splitter='best', 
                            max_depth=None, min_samples_split=2, 
                            min_samples_leaf=1, class_weight=None)

#train model + measure time
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify data + measure time
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#read csv
sea_a = pd.read_csv('data/sea_a.csv')

#get features and target class
X = sea_a.drop(sea_a.iloc[:,-1:], axis=1)
y = sea_a.iloc[:,-1:]

#set train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =(test/len(sea_a)), random_state = 42)

#set classifier
dt = DecisionTreeClassifier(criterion='gini', splitter='best', 
                            max_depth=None, min_samples_split=2, 
                            min_samples_leaf=1, class_weight=None)

#train model + measure
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify data + measure
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#read csv
sea_g1 = pd.read_csv('data/sea_g1.csv')

#get features and target class
X = sea_g1.drop(sea_g1.iloc[:,-1:], axis=1)
y = sea_g1.iloc[:,-1:]

#set train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = (test/len(sea_g1)), random_state = 42)

#set classifier
dt = DecisionTreeClassifier(criterion='gini', splitter='best', 
                            max_depth=None, min_samples_split=2, 
                            min_samples_leaf=1, class_weight=None)

#train model + measure
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify data + measure
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#read csv
sea_g2 = pd.read_csv('data/sea_g2.csv')

#get features and target class
X = sea_g2.drop(sea_g2.iloc[:,-1:], axis=1)
y = sea_g2.iloc[:,-1:]

#set train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = (test/len(sea_g2)), random_state = 42)

#set classifier
dt = DecisionTreeClassifier(criterion='gini', splitter='best', 
                            max_depth=None, min_samples_split=2, 
                            min_samples_leaf=1, class_weight=None)

#train model + measure
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify data + measure
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#read csv
agr_a = pd.read_csv('data/agr_a.csv')

#get features and target class
X = agr_a.drop(agr_a.iloc[:,-1:], axis=1)
y = agr_a.iloc[:,-1:]

#set train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = (test/len(agr_a)), random_state = 42)

#set classifier
dt = DecisionTreeClassifier(criterion='gini', splitter='best', 
                            max_depth=None, min_samples_split=2, 
                            min_samples_leaf=1, class_weight=None)

#train model + measure
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify data + measure
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#read csv
agr_g1 = pd.read_csv('data/agr_g1.csv')

#get features and target class
X = agr_g1.drop(agr_g1.iloc[:,-1:], axis=1)
y = agr_g1.iloc[:,-1:]

#set train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = (test/len(agr_g1)), random_state = 42)

#set classifier
dt = DecisionTreeClassifier(criterion='gini', splitter='best', 
                            max_depth=None, min_samples_split=2, 
                            min_samples_leaf=1, class_weight=None)

#train model + measure
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify data + measure
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#read csv
agr_g2 = pd.read_csv('data/agr_g2.csv')

#get features and target class
X = agr_g2.drop(agr_g2.iloc[:,-1:], axis=1)
y = agr_g2.iloc[:,-1:]

#set train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = (test/len(agr_g2)), random_state = 42)

#set classifier
dt = DecisionTreeClassifier(criterion='gini', splitter='best', 
                            max_depth=None, min_samples_split=2, 
                            min_samples_leaf=1, class_weight=None)

#train model + measure
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify data + measure
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#read csv
air = pd.read_csv('https://raw.githubusercontent.com/scikit-multiflow/streaming-datasets/master/airlines.csv')

#get features and target class
X = air.drop(air.iloc[:,-1:], axis=1)
y = air.iloc[:,-1:]

#set train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = (test/len(air)), random_state = 42)

#set classifier
dt = DecisionTreeClassifier(criterion='gini', splitter='best', 
                            max_depth=None, min_samples_split=2, 
                            min_samples_leaf=1, class_weight=None)

#train model + measure
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify data + measure
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
#read csv
cov = pd.read_csv('data/covtype.csv')

#get features and target class
X = cov.drop(cov.iloc[:,-1:], axis=1)
y = cov.iloc[:,-1:]

#set train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = (test/len(cov)), random_state = 42)

#set classifier
dt = DecisionTreeClassifier(criterion='gini', splitter='best', 
                            max_depth=None, min_samples_split=2, 
                            min_samples_leaf=1, class_weight=None)

#train model + measure
start_train = time.time()
dt.fit(X_train, y_train)
stop_train = time.time() 

#classify data + measure
start_pred = time.time()
y_pred = dt.predict(X_test)
stop_pred = time.time()

#evaluate prediction
evaluate()

# %%
result= {
    'Datensatz':['led_g1', 'led_g2', 'sea_a', 'sea_g1', 
                 'sea_g2', 'agr_a', 'agr_g1', 'agr_g2', 'air', 'cov'],
    'Accuracy' :accuracy,
    'Kappa':kappa,
    'Precision':precision,
    'Recall':recall,
    'f1':f1,
    'Train Time':train_time,
    'Prediction Time':pred_time
          }
result = pd.DataFrame(result)
print(result)
# Out:
#   Datensatz  Accuracy     Kappa  Precision  Recall        f1  Train Time  \
# 0    led_g1     0.638  0.597356   0.638245   0.638  0.637883    0.736132
# 1    led_g2     0.149  0.054190   0.151672   0.149  0.149868    0.735219
# 2     sea_a     0.984  0.966213   0.984064   0.984  0.984016    0.386009
# 3    sea_g1     0.991  0.980259   0.991008   0.991  0.991003    0.501476
# 4    sea_g2     0.624  0.228826   0.625342   0.624  0.624609    1.714255
# 5     agr_a     0.977  0.952713   0.976994   0.977  0.976996    0.712366
# 6    agr_g1     0.988  0.974083   0.988023   0.988  0.988007    0.701782
# 7    agr_g2     0.766  0.498764   0.764335   0.766  0.764965    0.782565
# 8       air     0.600  0.170844   0.594232   0.600  0.592173    2.944362
# 9       cov     0.955  0.929088   0.956433   0.955  0.955164   10.822207
#
#    Prediction Time
# 0         0.002659
# 1         0.003946
# 2         0.001598
# 3         0.001563
# 4         0.002402
# 5         0.001457
# 6         0.001346
# 7         0.001904
# 8         0.005854
# 9         0.003215

# %%
result.to_excel('results_dt.xlsx')
