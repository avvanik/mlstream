# %% [markdown]
# In diesem Notebook wird eine Delayed Streaming Klassifizierung für t_sea_g2 mit V = 500 durchgeführt

# %%
import numpy as np
import pandas as pd

from skmultiflow.trees import HoeffdingTreeClassifier
from skmultiflow.trees import HoeffdingAdaptiveTreeClassifier
from skmultiflow.trees import ExtremelyFastDecisionTreeClassifier
from skmultiflow.meta import AdaptiveRandomForestClassifier
from skmultiflow.bayes import NaiveBayes
from skmultiflow.meta import AccuracyWeightedEnsembleClassifier
from skmultiflow.lazy import KNNADWINClassifier

from skmultiflow.data import TemporalDataStream

from skmultiflow.evaluation import EvaluatePrequentialDelayed

# %%
import warnings
warnings.filterwarnings('ignore')

#set columns
attribute = ['att_num_0', 'att_num_1', 'att_num_2']
target = 'target_0'
timestamp = 'datetime'

#read csv
t_sea_g2 = pd.read_csv("t_sea_g2.csv")

#convert time to datetime
t_sea_g2[timestamp] = pd.to_datetime(t_sea_g2[timestamp])

#get X, y and time
X = t_sea_g2[attribute].values
y = t_sea_g2[target].values
time = t_sea_g2[timestamp].values

#set delay
delay_time = 500

#create stream
t_sea_g2_stream = TemporalDataStream(X, y, time, sample_delay=delay_time, ordered=False)

#set classifier
ht = HoeffdingTreeClassifier(leaf_prediction='nb')
hat = HoeffdingAdaptiveTreeClassifier()
efdt = ExtremelyFastDecisionTreeClassifier()
arf = AdaptiveRandomForestClassifier()
snb = NaiveBayes()
awe = AccuracyWeightedEnsembleClassifier(n_estimators=15, base_estimator=NaiveBayes())
knn_adwin = KNNADWINClassifier(n_neighbors=10)

#set evaluator
evaluator = EvaluatePrequentialDelayed(
                                max_samples=X.shape[0],
                                n_wait=10,
                                pretrain_size=100,
                                output_file='results_t_sea_g2.csv',
                                metrics=['accuracy', 'kappa', 
                                         'precision', 'recall', 
                                         'f1', 'running_time', 
                                         'model_size'])

#evaluate
evaluator.evaluate(stream=t_sea_g2_stream, 
                   model=[ht, hat, efdt, arf, 
                          snb, awe, knn_adwin], 
                   model_names=['Hoeffding Tree', 'Hoeffding Adaptive Tree', 
                                'Extremely Fast Decision Tree', 
                                'Adaptive Random Forest', 
                                'Naive Bayes', 'Accuracy Weighted Ensembler', 'KNN ADWIN' ])
# Out:
# Prequential Evaluation Delayed
# Evaluating 1 target(s).
# Pre-training on 100 sample(s).
# Evaluating...
#  ###################- [95%] [292.99s]Processed samples: 10000
# Mean performance:
# Hoeffding Tree - Accuracy     : 0.7207
# Hoeffding Tree - Kappa        : 0.4262
# Hoeffding Tree - Precision: 0.7250
# Hoeffding Tree - Recall: 0.8025
# Hoeffding Tree - F1 score: 0.7618
# Hoeffding Tree - Training time (s)  : 0.72
# Hoeffding Tree - Testing time  (s)  : 0.83
# Hoeffding Tree - Total time    (s)  : 1.54
# Hoeffding Tree - Size (kB)          : 26.6875
# Hoeffding Adaptive Tree - Accuracy     : 0.7177
# Hoeffding Adaptive Tree - Kappa        : 0.4228
# Hoeffding Adaptive Tree - Precision: 0.7297
# Hoeffding Adaptive Tree - Recall: 0.7827
# Hoeffding Adaptive Tree - F1 score: 0.7553
# Hoeffding Adaptive Tree - Training time (s)  : 2.80
# Hoeffding Adaptive Tree - Testing time  (s)  : 0.76
# Hoeffding Adaptive Tree - Total time    (s)  : 3.56
# Hoeffding Adaptive Tree - Size (kB)          : 102.4004
# Extremely Fast Decision Tree - Accuracy     : 0.7190
# Extremely Fast Decision Tree - Kappa        : 0.4261
# Extremely Fast Decision Tree - Precision: 0.7326
# Extremely Fast Decision Tree - Recall: 0.7798
# Extremely Fast Decision Tree - F1 score: 0.7555
# Extremely Fast Decision Tree - Training time (s)  : 17.82
# Extremely Fast Decision Tree - Testing time  (s)  : 0.54
# Extremely Fast Decision Tree - Total time    (s)  : 18.36
# Extremely Fast Decision Tree - Size (kB)          : 52.1504
# Adaptive Random Forest - Accuracy     : 0.7212
# Adaptive Random Forest - Kappa        : 0.4297
# Adaptive Random Forest - Precision: 0.7324
# Adaptive Random Forest - Recall: 0.7864
# Adaptive Random Forest - F1 score: 0.7584
# Adaptive Random Forest - Training time (s)  : 60.17
# Adaptive Random Forest - Testing time  (s)  : 5.02
# Adaptive Random Forest - Total time    (s)  : 65.19
# Adaptive Random Forest - Size (kB)          : 10545.3457
# Naive Bayes - Accuracy     : 0.7281
# Naive Bayes - Kappa        : 0.4414
# Naive Bayes - Precision: 0.7305
# Naive Bayes - Recall: 0.8105
# Naive Bayes - F1 score: 0.7684
# Naive Bayes - Training time (s)  : 0.28
# Naive Bayes - Testing time  (s)  : 0.51
# Naive Bayes - Total time    (s)  : 0.79
# Naive Bayes - Size (kB)          : 6.2764
# Accuracy Weighted Ensembler - Accuracy     : 0.7143
# Accuracy Weighted Ensembler - Kappa        : 0.4181
# Accuracy Weighted Ensembler - Precision: 0.7336
# Accuracy Weighted Ensembler - Recall: 0.7642
# Accuracy Weighted Ensembler - F1 score: 0.7486
# Accuracy Weighted Ensembler - Training time (s)  : 5.74
# Accuracy Weighted Ensembler - Testing time  (s)  : 5.24
# Accuracy Weighted Ensembler - Total time    (s)  : 10.98
# Accuracy Weighted Ensembler - Size (kB)          : 222.1768
# KNN ADWIN - Accuracy     : 0.7101
# KNN ADWIN - Kappa        : 0.4117
# KNN ADWIN - Precision: 0.7361
# KNN ADWIN - Recall: 0.7470
# KNN ADWIN - F1 score: 0.7415
# KNN ADWIN - Training time (s)  : 5.81
# KNN ADWIN - Testing time  (s)  : 4.07
# KNN ADWIN - Total time    (s)  : 9.88
# KNN ADWIN - Size (kB)          : 372.8525
# [HoeffdingTreeClassifier(binary_split=False, grace_period=200,
#                          leaf_prediction='nb', max_byte_size=33554432,
#                          memory_estimate_period=1000000, nb_threshold=0,
#                          no_preprune=False, nominal_attributes=None,
#                          remove_poor_atts=False, split_confidence=1e-07,
#                          split_criterion='info_gain', stop_mem_management=False,
#                          tie_threshold=0.05),
#  HoeffdingAdaptiveTreeClassifier(binary_split=False, bootstrap_sampling=True,
#                                  grace_period=200, leaf_prediction='nba',
#                                  max_byte_size=33554432,
#                                  memory_estimate_period=1000000, nb_threshold=0,
#                                  no_preprune=False, nominal_attributes=None,
#                                  random_state=None, remove_poor_atts=False,
#                                  split_confidence=1e-07,
#                                  split_criterion='info_gain',
#                                  stop_mem_management=False, tie_threshold=0.05),
#  ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                      leaf_prediction='nba',
#                                      max_byte_size=33554432,
#                                      memory_estimate_period=1000000,
#                                      min_samples_reevaluate=20, nb_threshold=0,
#                                      nominal_attributes=None,
#                                      split_confidence=1e-07,
#                                      split_criterion='info_gain',
#                                      stop_mem_management=False,
#                                      tie_threshold=0.05),
#  AdaptiveRandomForestClassifier(binary_split=False, disable_weighted_vote=False,
#                                 drift_detection_method=ADWIN(delta=0.001),
#                                 grace_period=50, lambda_value=6,
#                                 leaf_prediction='nba', max_byte_size=33554432,
#                                 max_features=2, memory_estimate_period=2000000,
#                                 n_estimators=10, nb_threshold=0,
#                                 no_preprune=False, nominal_attributes=None,
#                                 performance_metric='acc', random_state=None,
#                                 remove_poor_atts=False, split_confidence=0.01,
#                                 split_criterion='info_gain',
#                                 stop_mem_management=False, tie_threshold=0.05,
#                                 warning_detection_method=ADWIN(delta=0.01)),
#  NaiveBayes(nominal_attributes=None),
#  AccuracyWeightedEnsembleClassifier(base_estimator=NaiveBayes(nominal_attributes=None),
#                                     n_estimators=15, n_kept_estimators=30,
#                                     n_splits=5, window_size=200),
#  KNNADWINClassifier(leaf_size=30, max_window_size=1000, metric='euclidean',
#                     n_neighbors=10)]
