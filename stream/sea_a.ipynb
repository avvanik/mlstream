# %% [markdown]
# Streaming Klassifizierung der sea_a Daten

# %%
import numpy as np
import pandas as pd

from skmultiflow.trees import HoeffdingTreeClassifier
from skmultiflow.trees import HoeffdingAdaptiveTreeClassifier
from skmultiflow.trees import ExtremelyFastDecisionTreeClassifier
from skmultiflow.meta import AdaptiveRandomForestClassifier
from skmultiflow.bayes import NaiveBayes
from skmultiflow.meta import AccuracyWeightedEnsembleClassifier
from skmultiflow.lazy import KNNADWINClassifier

from skmultiflow.data.file_stream import FileStream

from skmultiflow.evaluation import EvaluatePrequential

# %%
sea_a_stream = FileStream('data/sea_a.csv')

ht = HoeffdingTreeClassifier(leaf_prediction='nb')
hat = HoeffdingAdaptiveTreeClassifier()
efdt = ExtremelyFastDecisionTreeClassifier()
arf = AdaptiveRandomForestClassifier()
snb = NaiveBayes()
awe = AccuracyWeightedEnsembleClassifier(n_estimators=15, base_estimator=NaiveBayes())
knn_adwin = KNNADWINClassifier(n_neighbors=10)

evaluator = EvaluatePrequential(max_samples=100000,
                                n_wait=100,
                                pretrain_size=100,
                                output_file='results_sea_a_stream.csv',
                                metrics=['accuracy', 'kappa', 
                                         'precision', 'recall', 
                                         'f1', 'running_time', 
                                         'model_size'])

evaluator.evaluate(stream=sea_a_stream, 
                   model=[ht, hat, efdt, arf, 
                          snb, awe, knn_adwin], 
                   model_names=['Hoeffding Tree', 'Hoeffding Adaptive Tree', 
                                'Extremely Fast Decision Tree', 
                                'Adaptive Random Forest', 
                                'Naive Bayes', 'Accuracy Weighted Ensembler', 'KNN ADWIN'])
# Out:
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 100 sample(s).
# Evaluating...
#  #################### [100%] [1355.51s]
# Processed samples: 100000
# Mean performance:
# Hoeffding Tree - Accuracy     : 0.9538
# Hoeffding Tree - Kappa        : 0.9022
# Hoeffding Tree - Precision: 0.9634
# Hoeffding Tree - Recall: 0.9620
# Hoeffding Tree - F1 score: 0.9627
# Hoeffding Tree - Training time (s)  : 5.91
# Hoeffding Tree - Testing time  (s)  : 8.63
# Hoeffding Tree - Total time    (s)  : 14.53
# Hoeffding Tree - Size (kB)          : 227.1680
# Hoeffding Adaptive Tree - Accuracy     : 0.9603
# Hoeffding Adaptive Tree - Kappa        : 0.9157
# Hoeffding Adaptive Tree - Precision: 0.9654
# Hoeffding Adaptive Tree - Recall: 0.9707
# Hoeffding Adaptive Tree - F1 score: 0.9680
# Hoeffding Adaptive Tree - Training time (s)  : 42.74
# Hoeffding Adaptive Tree - Testing time  (s)  : 8.56
# Hoeffding Adaptive Tree - Total time    (s)  : 51.30
# Hoeffding Adaptive Tree - Size (kB)          : 282.7246
# Extremely Fast Decision Tree - Accuracy     : 0.9419
# Extremely Fast Decision Tree - Kappa        : 0.8764
# Extremely Fast Decision Tree - Precision: 0.9486
# Extremely Fast Decision Tree - Recall: 0.9580
# Extremely Fast Decision Tree - F1 score: 0.9533
# Extremely Fast Decision Tree - Training time (s)  : 456.59
# Extremely Fast Decision Tree - Testing time  (s)  : 6.41
# Extremely Fast Decision Tree - Total time    (s)  : 463.00
# Extremely Fast Decision Tree - Size (kB)          : 132.4277
# Adaptive Random Forest - Accuracy     : 0.9731
# Adaptive Random Forest - Kappa        : 0.9428
# Adaptive Random Forest - Precision: 0.9746
# Adaptive Random Forest - Recall: 0.9821
# Adaptive Random Forest - F1 score: 0.9783
# Adaptive Random Forest - Training time (s)  : 425.96
# Adaptive Random Forest - Testing time  (s)  : 54.10
# Adaptive Random Forest - Total time    (s)  : 480.05
# Adaptive Random Forest - Size (kB)          : 4297.4434
# Naive Bayes - Accuracy     : 0.9270
# Naive Bayes - Kappa        : 0.8416
# Naive Bayes - Precision: 0.9110
# Naive Bayes - Recall: 0.9775
# Naive Bayes - F1 score: 0.9431
# Naive Bayes - Training time (s)  : 3.40
# Naive Bayes - Testing time  (s)  : 5.68
# Naive Bayes - Total time    (s)  : 9.08
# Naive Bayes - Size (kB)          : 7.7881
# Accuracy Weighted Ensembler - Accuracy     : 0.8817
# Accuracy Weighted Ensembler - Kappa        : 0.7460
# Accuracy Weighted Ensembler - Precision: 0.8888
# Accuracy Weighted Ensembler - Recall: 0.9245
# Accuracy Weighted Ensembler - F1 score: 0.9063
# Accuracy Weighted Ensembler - Training time (s)  : 94.98
# Accuracy Weighted Ensembler - Testing time  (s)  : 71.44
# Accuracy Weighted Ensembler - Total time    (s)  : 166.41
# Accuracy Weighted Ensembler - Size (kB)          : 273.7314
# KNN ADWIN - Accuracy     : 0.6066
# KNN ADWIN - Kappa        : 0.1469
# KNN ADWIN - Precision: 0.6699
# KNN ADWIN - Recall: 0.7182
# KNN ADWIN - F1 score: 0.6932
# KNN ADWIN - Training time (s)  : 54.39
# KNN ADWIN - Testing time  (s)  : 36.21
# KNN ADWIN - Total time    (s)  : 90.61
# KNN ADWIN - Size (kB)          : 413.7041
# [HoeffdingTreeClassifier(binary_split=False, grace_period=200,
#                          leaf_prediction='nb', max_byte_size=33554432,
#                          memory_estimate_period=1000000, nb_threshold=0,
#                          no_preprune=False, nominal_attributes=None,
#                          remove_poor_atts=False, split_confidence=1e-07,
#                          split_criterion='info_gain', stop_mem_management=False,
#                          tie_threshold=0.05),
#  HoeffdingAdaptiveTreeClassifier(binary_split=False, bootstrap_sampling=True,
#                                  grace_period=200, leaf_prediction='nba',
#                                  max_byte_size=33554432,
#                                  memory_estimate_period=1000000, nb_threshold=0,
#                                  no_preprune=False, nominal_attributes=None,
#                                  random_state=None, remove_poor_atts=False,
#                                  split_confidence=1e-07,
#                                  split_criterion='info_gain',
#                                  stop_mem_management=False, tie_threshold=0.05),
#  ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                      leaf_prediction='nba',
#                                      max_byte_size=33554432,
#                                      memory_estimate_period=1000000,
#                                      min_samples_reevaluate=20, nb_threshold=0,
#                                      nominal_attributes=None,
#                                      split_confidence=1e-07,
#                                      split_criterion='info_gain',
#                                      stop_mem_management=False,
#                                      tie_threshold=0.05),
#  AdaptiveRandomForestClassifier(binary_split=False, disable_weighted_vote=False,
#                                 drift_detection_method=ADWIN(delta=0.001),
#                                 grace_period=50, lambda_value=6,
#                                 leaf_prediction='nba', max_byte_size=33554432,
#                                 max_features=2, memory_estimate_period=2000000,
#                                 n_estimators=10, nb_threshold=0,
#                                 no_preprune=False, nominal_attributes=None,
#                                 performance_metric='acc', random_state=None,
#                                 remove_poor_atts=False, split_confidence=0.01,
#                                 split_criterion='info_gain',
#                                 stop_mem_management=False, tie_threshold=0.05,
#                                 warning_detection_method=ADWIN(delta=0.01)),
#  NaiveBayes(nominal_attributes=None),
#  AccuracyWeightedEnsembleClassifier(base_estimator=NaiveBayes(nominal_attributes=None),
#                                     n_estimators=15, n_kept_estimators=30,
#                                     n_splits=5, window_size=200),
#  KNNADWINClassifier(leaf_size=30, max_window_size=1000, metric='euclidean',
#                     n_neighbors=10)]
