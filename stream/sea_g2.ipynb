# %% [markdown]
# Streaming Klassifizierung der sea_g2 Daten

# %%
import numpy as np
import pandas as pd

from skmultiflow.trees import HoeffdingTreeClassifier
from skmultiflow.trees import HoeffdingAdaptiveTreeClassifier
from skmultiflow.trees import ExtremelyFastDecisionTreeClassifier
from skmultiflow.meta import AdaptiveRandomForestClassifier
from skmultiflow.bayes import NaiveBayes
from skmultiflow.meta import AccuracyWeightedEnsembleClassifier
from skmultiflow.lazy import KNNADWINClassifier

from skmultiflow.data.file_stream import FileStream

from skmultiflow.evaluation import EvaluatePrequential

# %%
#create stream
sea_g2_stream = FileStream('data/sea_g2.csv') 

#set classifier
ht = HoeffdingTreeClassifier(leaf_prediction='nb')
hat = HoeffdingAdaptiveTreeClassifier()
efdt = ExtremelyFastDecisionTreeClassifier()
arf = AdaptiveRandomForestClassifier()
snb = NaiveBayes()
awe = AccuracyWeightedEnsembleClassifier(n_estimators=15, base_estimator=NaiveBayes())
knn_adwin = KNNADWINClassifier(n_neighbors=10)

#set evaluator
evaluator = EvaluatePrequential(max_samples=100000,
                                n_wait=100,
                                pretrain_size=100,
                                output_file='results_sea_g2_stream.csv',
                                metrics=['accuracy', 'kappa', 
                                         'precision', 'recall', 
                                         'f1', 'running_time', 
                                         'model_size'])

#evaluate
evaluator.evaluate(stream=sea_g2_stream, 
                   model=[ht, hat, efdt, arf, 
                          snb, awe, knn_adwin], 
                   model_names=['Hoeffding Tree', 'Hoeffding Adaptive Tree', 
                                'Extremely Fast Decision Tree', 
                                'Adaptive Random Forest', 
                                'Naive Bayes', 'Accuracy Weighted Ensembler', 'KNN ADWIN'])
# Out:
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 100 sample(s).
# Evaluating...
#  #################### [100%] [2322.88s]
# Processed samples: 100000
# Mean performance:
# Hoeffding Tree - Accuracy     : 0.7369
# Hoeffding Tree - Kappa        : 0.4506
# Hoeffding Tree - Precision: 0.7458
# Hoeffding Tree - Recall: 0.8251
# Hoeffding Tree - F1 score: 0.7834
# Hoeffding Tree - Training time (s)  : 6.55
# Hoeffding Tree - Testing time  (s)  : 9.57
# Hoeffding Tree - Total time    (s)  : 16.13
# Hoeffding Tree - Size (kB)          : 234.9180
# Hoeffding Adaptive Tree - Accuracy     : 0.7339
# Hoeffding Adaptive Tree - Kappa        : 0.4419
# Hoeffding Adaptive Tree - Precision: 0.7386
# Hoeffding Adaptive Tree - Recall: 0.8336
# Hoeffding Adaptive Tree - F1 score: 0.7832
# Hoeffding Adaptive Tree - Training time (s)  : 46.28
# Hoeffding Adaptive Tree - Testing time  (s)  : 7.70
# Hoeffding Adaptive Tree - Total time    (s)  : 53.98
# Hoeffding Adaptive Tree - Size (kB)          : 532.5918
# Extremely Fast Decision Tree - Accuracy     : 0.7150
# Extremely Fast Decision Tree - Kappa        : 0.4048
# Extremely Fast Decision Tree - Precision: 0.7284
# Extremely Fast Decision Tree - Recall: 0.8066
# Extremely Fast Decision Tree - F1 score: 0.7655
# Extremely Fast Decision Tree - Training time (s)  : 429.04
# Extremely Fast Decision Tree - Testing time  (s)  : 5.69
# Extremely Fast Decision Tree - Total time    (s)  : 434.73
# Extremely Fast Decision Tree - Size (kB)          : 106.7480
# Adaptive Random Forest - Accuracy     : 0.7403
# Adaptive Random Forest - Kappa        : 0.4568
# Adaptive Random Forest - Precision: 0.7467
# Adaptive Random Forest - Recall: 0.8318
# Adaptive Random Forest - F1 score: 0.7869
# Adaptive Random Forest - Training time (s)  : 830.84
# Adaptive Random Forest - Testing time  (s)  : 61.63
# Adaptive Random Forest - Total time    (s)  : 892.48
# Adaptive Random Forest - Size (kB)          : 52865.4238
# Naive Bayes - Accuracy     : 0.7383
# Naive Bayes - Kappa        : 0.4517
# Naive Bayes - Precision: 0.7431
# Naive Bayes - Recall: 0.8348
# Naive Bayes - F1 score: 0.7863
# Naive Bayes - Training time (s)  : 3.31
# Naive Bayes - Testing time  (s)  : 5.63
# Naive Bayes - Total time    (s)  : 8.94
# Naive Bayes - Size (kB)          : 7.7881
# Accuracy Weighted Ensembler - Accuracy     : 0.6391
# Accuracy Weighted Ensembler - Kappa        : 0.2552
# Accuracy Weighted Ensembler - Precision: 0.6797
# Accuracy Weighted Ensembler - Recall: 0.7077
# Accuracy Weighted Ensembler - F1 score: 0.6934
# Accuracy Weighted Ensembler - Training time (s)  : 96.75
# Accuracy Weighted Ensembler - Testing time  (s)  : 74.69
# Accuracy Weighted Ensembler - Total time    (s)  : 171.44
# Accuracy Weighted Ensembler - Size (kB)          : 273.6689
# KNN ADWIN - Accuracy     : 0.5342
# KNN ADWIN - Kappa        : 0.0467
# KNN ADWIN - Precision: 0.5966
# KNN ADWIN - Recall: 0.5937
# KNN ADWIN - F1 score: 0.5951
# KNN ADWIN - Training time (s)  : 54.31
# KNN ADWIN - Testing time  (s)  : 37.20
# KNN ADWIN - Total time    (s)  : 91.50
# KNN ADWIN - Size (kB)          : 414.5908
# [HoeffdingTreeClassifier(binary_split=False, grace_period=200,
#                          leaf_prediction='nb', max_byte_size=33554432,
#                          memory_estimate_period=1000000, nb_threshold=0,
#                          no_preprune=False, nominal_attributes=None,
#                          remove_poor_atts=False, split_confidence=1e-07,
#                          split_criterion='info_gain', stop_mem_management=False,
#                          tie_threshold=0.05),
#  HoeffdingAdaptiveTreeClassifier(binary_split=False, bootstrap_sampling=True,
#                                  grace_period=200, leaf_prediction='nba',
#                                  max_byte_size=33554432,
#                                  memory_estimate_period=1000000, nb_threshold=0,
#                                  no_preprune=False, nominal_attributes=None,
#                                  random_state=None, remove_poor_atts=False,
#                                  split_confidence=1e-07,
#                                  split_criterion='info_gain',
#                                  stop_mem_management=False, tie_threshold=0.05),
#  ExtremelyFastDecisionTreeClassifier(binary_split=False, grace_period=200,
#                                      leaf_prediction='nba',
#                                      max_byte_size=33554432,
#                                      memory_estimate_period=1000000,
#                                      min_samples_reevaluate=20, nb_threshold=0,
#                                      nominal_attributes=None,
#                                      split_confidence=1e-07,
#                                      split_criterion='info_gain',
#                                      stop_mem_management=False,
#                                      tie_threshold=0.05),
#  AdaptiveRandomForestClassifier(binary_split=False, disable_weighted_vote=False,
#                                 drift_detection_method=ADWIN(delta=0.001),
#                                 grace_period=50, lambda_value=6,
#                                 leaf_prediction='nba', max_byte_size=33554432,
#                                 max_features=2, memory_estimate_period=2000000,
#                                 n_estimators=10, nb_threshold=0,
#                                 no_preprune=False, nominal_attributes=None,
#                                 performance_metric='acc', random_state=None,
#                                 remove_poor_atts=False, split_confidence=0.01,
#                                 split_criterion='info_gain',
#                                 stop_mem_management=False, tie_threshold=0.05,
#                                 warning_detection_method=ADWIN(delta=0.01)),
#  NaiveBayes(nominal_attributes=None),
#  AccuracyWeightedEnsembleClassifier(base_estimator=NaiveBayes(nominal_attributes=None),
#                                     n_estimators=15, n_kept_estimators=30,
#                                     n_splits=5, window_size=200),
#  KNNADWINClassifier(leaf_size=30, max_window_size=1000, metric='euclidean',
#                     n_neighbors=10)]
